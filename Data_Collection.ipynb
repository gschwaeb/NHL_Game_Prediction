# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
import statsmodels.api as sm
import hockey_scraper
import pickle
import time
import random
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Define Helper Functions

# %%
nst_to_sched = { 'Anaheim Ducks': 'ANA', 
                      'Arizona Coyotes' : 'ARI', 
                      'Boston Bruins': 'BOS', 
                      'Buffalo Sabres':'BUF',
                      'Calgary Flames': 'CGY', 
                      'Carolina Hurricanes': 'CAR', 
                      'Chicago Blackhawks': 'CHI', 
                      'Colorado Avalanche': 'COL',
                     'Columbus Blue Jackets': 'CBJ',
                     'Dallas Stars': 'DAL',
                     'Detroit Red Wings': 'DET',
                     'Edmonton Oilers': 'EDM',
                     'Florida Panthers': 'FLA',
                     'Los Angeles Kings': 'L.A.',
                     'Minnesota Wild': 'MIN',
                     'Montreal Canadiens': 'MTL',
                     'Nashville Predators': 'NSH',
                     'New Jersey Devils': 'N.J.',
                     'New York Islanders': 'NYI',
                     'New York Rangers': 'NYR',
                     'Ottawa Senators': 'OTT',
                     'Philadelphia Flyers': 'PHI',
                     'Pittsburgh Penguins': 'PIT',
                     'San Jose Sharks': 'S.J.',
                     'St. Louis Blues': 'STL',
                     'Tampa Bay Lightning': 'T.B.',
                     'Toronto Maple Leafs': 'TOR',
                     'Vancouver Canucks': 'VAN',
                      'Vegas Golden Knights':'VGK',
                     'Washington Capitals': 'WSH',
                     'Winnipeg Jets': 'WPG'}

# %%
#scrape NST
def get_and_format_nst_team_stats(season, sit, rate):
    nst_to_sched = {'Anaheim Ducks': 'ANA',
                     'Arizona Coyotes': 'ARI',
                     'Boston Bruins': 'BOS',
                     'Buffalo Sabres': 'BUF',
                     'Calgary Flames': 'CGY',
                     'Carolina Hurricanes': 'CAR',
                     'Chicago Blackhawks': 'CHI',
                     'Colorado Avalanche': 'COL',
                     'Columbus Blue Jackets': 'CBJ',
                     'Dallas Stars': 'DAL',
                     'Detroit Red Wings': 'DET',
                     'Edmonton Oilers': 'EDM',
                     'Florida Panthers': 'FLA',
                     'Los Angeles Kings': 'L.A',
                     'Minnesota Wild': 'MIN',
                     'Montreal Canadiens': 'MTL',
                     'Nashville Predators': 'NSH',
                     'New Jersey Devils': 'N.J',
                     'New York Islanders': 'NYI',
                     'New York Rangers': 'NYR',
                     'Ottawa Senators': 'OTT',
                     'Philadelphia Flyers': 'PHI',
                     'Pittsburgh Penguins': 'PIT',
                     'San Jose Sharks': 'S.J',
                     'St Louis Blues': 'STL',
                     'Tampa Bay Lightning': 'T.B',
                     'Toronto Maple Leafs': 'TOR',
                     'Vancouver Canucks': 'VAN',
                     'Vegas Golden Knights': 'VGK',
                     'Washington Capitals': 'WSH',
                     'Winnipeg Jets': 'WPG'}
    
    url = 'https://www.naturalstattrick.com/games.php?fromseason={}&thruseason={}&stype=2&sit={}&loc=B&team=All&rate={}'.format(
        season,
        season,
        sit,
        rate)
    df = pd.read_html(url, header=0, index_col = 0, na_values=["-"])[0]
    df.reset_index(inplace = True)
    df['Date'] = df['Game'].apply(lambda x: pd.to_datetime(x[0:10]))
    df['Game_Number'] = df.groupby('Team').cumcount() + 1
    #rename Team_Date to team key or something like that
    df = df.replace({'Team': nst_to_sched})

    df['Team_Key'] = df['Team'].astype(str)+'_'+df['Date'].astype(str)
    return df

# %%
def merge_team_stats(primary_df, pp_df, pk_df):
    primary_df = primary_df.merge(pk_df[['Team_Key', 'TOI', 'xGA', 'GA']], on = 'Team_Key', how = 'left', suffixes = ('','_pk') )
    primary_df = primary_df.merge(pp_df[['Team_Key', 'TOI', 'xGF', 'GF']], on = 'Team_Key', how = 'left', suffixes = ('','_pp') )
    return primary_df

# %%
def calculate_team_features(df, rolling_games = 20):

    df[f'sum_rolling{rolling_games}_TOI_5v5'] = df.groupby('Team')['TOI'].transform(lambda x: x.rolling(rolling_games, rolling_games).sum().shift())
    df[f'sum_rolling{rolling_games}_FF_5v5'] = df.groupby('Team')['FF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_FA_5v5'] = df.groupby('Team')['FA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GF_5v5'] = df.groupby('Team')['GF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GA_5v5'] = df.groupby('Team')['GA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGF_5v5'] = df.groupby('Team')['xGF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGA_5v5'] = df.groupby('Team')['xGA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_SF_5v5'] = df.groupby('Team')['SF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last_{rolling_games}_FF%_5v5'] = df[f'sum_rolling{rolling_games}_FF_5v5']*100/ (df[f'sum_rolling{rolling_games}_FF_5v5']+df[f'sum_rolling{rolling_games}_FA_5v5'])
    df[f'last_{rolling_games}_GF%_5v5'] = df[f'sum_rolling{rolling_games}_GF_5v5']*100/ (df[f'sum_rolling{rolling_games}_GF_5v5']+df[f'sum_rolling{rolling_games}_GA_5v5'])
    df[f'last_{rolling_games}_xGF%_5v5'] = df[f'sum_rolling{rolling_games}_xGF_5v5']*100/ (df[f'sum_rolling{rolling_games}_xGF_5v5']+df[f'sum_rolling{rolling_games}_xGA_5v5'])
    df[f'last_{rolling_games}_SH%'] = df[f'sum_rolling{rolling_games}_GF_5v5']*100 / df[f'sum_rolling{rolling_games}_SF_5v5']
    
    
    #fix NaNs in pp and pk features
    df['TOI_pp'] = np.where(df['TOI_pp'].isna(), 0, df['TOI_pp'])
    df['TOI_pk'] = np.where(df['TOI_pk'].isna(), 0, df['TOI_pk'])
    df['xGF_pp'] = np.where(df['xGF_pp'].isna(), 0, df['xGF_pp'])
    df['GF_pp']  = np.where(df['GF_pp'].isna(), 0, df['GF_pp'])
    df['xGA_pk'] = np.where(df['xGA_pk'].isna(), 0, df['xGA_pk'])
    df['GA_pk']  = np.where(df['GA_pk'].isna(), 0, df['GA_pk'])
    
    #pp features
    df[f'sum_rolling{rolling_games}_TOI_pp'] = df.groupby('Team')['TOI_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGF_pp'] = df.groupby('Team')['xGF_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GF_pp'] = df.groupby('Team')['GF_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last{rolling_games}_pp_TOI_per_game'] = df.groupby('Team')['TOI_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).mean().shift())
    df[f'last{rolling_games}_xGF_per_min_pp'] = df[f'sum_rolling{rolling_games}_xGF_pp'] / df[f'sum_rolling{rolling_games}_TOI_pp'] 
    df[f'last{rolling_games}_GF_per_min_pp'] = df[f'sum_rolling{rolling_games}_GF_pp'] / df[f'sum_rolling{rolling_games}_TOI_pp'] 
    
    
    #pk features
    df[f'sum_rolling{rolling_games}_TOI_pk'] = df.groupby('Team')['TOI_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGA_pk'] = df.groupby('Team')['xGA_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GA_pk'] = df.groupby('Team')['GA_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last{rolling_games}_pk_TOI_per_game'] = df.groupby('Team')['TOI_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).mean().shift())
    df[f'last{rolling_games}_xGA_per_min_pk'] = df[f'sum_rolling{rolling_games}_xGA_pk'] / df[f'sum_rolling{rolling_games}_TOI_pk'] 
    df[f'last{rolling_games}_GA_per_min_pk'] = df[f'sum_rolling{rolling_games}_GA_pk'] / df[f'sum_rolling{rolling_games}_TOI_pk'] 
    
    #to get back to back category
    df['Last_Game_Date'] = df.groupby('Team')['Date'].shift()
    df['Days_Since_Last_Game'] = df['Date'] - df['Last_Game_Date']
    df['B2B'] = np.where(df['Days_Since_Last_Game'] == '1 days', 1, 0)
    
    

    
    return df

# %%
#get starters
def get_starters(year):
    goalie_table_teams = { 'ANA': 'ANA', 
                      'ARI' : 'ARI',
                      'BOS': 'BOS', 
                      'BUF':'BUF',
                      'CGY': 'CGY', 
                      'CAR': 'CAR', 
                      'CHI': 'CHI', 
                      'COL': 'COL',
                     'CBJ': 'CBJ',
                     'DAL': 'DAL',
                     'DET': 'DET',
                     'EDM': 'EDM',
                     'FLA': 'FLO',
                     'L.A': 'LOS',
                     'MIN': 'MIN',
                     'MTL': 'MON',
                     'NSH': 'NSH',
                     'N.J': 'NJD',
                     'NYI': 'NYI',
                     'NYR': 'NYR',
                     'OTT': 'OTT',
                     'PHI': 'PHI',
                     'PIT': 'PIT',
                     'S.J': 'SJS',
                     'STL': 'STL',
                     'T.B': 'TBL',
                     'TOR': 'TOR',
                     'VAN': 'VAN',
                     'WSH': 'WSH',
                     'WPG': 'WPG',
                     'VGK':'VGK'}
    counter = 0
    for k,v in goalie_table_teams.items():
        print(k)
        starter_url = 'http://hockeygoalies.org/bio/nhl/logs/{}{}.html'.format(v, year)
        goalies = pd.read_html(starter_url)[0]
        goalies.replace(to_replace=['(BU)', np.NaN], value = 'DNP', inplace = True)
        goalies.drop(columns = ['DEC'], inplace = True)
        goalies.drop(index  = goalies.iloc[-1].name, inplace = True)
        goalies['starter'] = 'placeholder'

        starter = []
        for i, row in goalies.iterrows():
            for n in range(len(row)):
                if row[n][0] == 'W' or row[n][0] == 'L':
                    starter.append(goalies.columns[n])

        goalies['starter'] = starter
        goalies['Team'] = k
        goalies['DATE'] = pd.to_datetime(goalies['DATE'])
        goalies['DATE'] = pd.to_datetime(goalies['DATE'])
        goalies['Team_Key'] = goalies['Team'].astype(str)+'_'+goalies['DATE'].astype(str)
        columns = ['Team','DATE', 'OPPONENT', 'starter', 'Team_Key']
        if counter == 0:
            master = goalies
        if counter != 0:
            master = pd.concat( [master[columns], goalies[columns]])
        counter +=1
    return master

# %%
#'2017-10-04' to '2018-04-08'
def get_game_results(season_start, season_end):
    sched_df = hockey_scraper.scrape_schedule(season_start, season_end)
    sched_df['Home_Team_Won'] = np.where(sched_df['home_score'] > sched_df['away_score'], 1, 0)
    sched_df['Home_Team_Key'] = sched_df['home_team'].astype(str)+'_'+sched_df['date'].astype(str)
    sched_df['Away_Team_Key'] = sched_df['away_team'].astype(str)+'_'+sched_df['date'].astype(str)
    return sched_df

# %%
def merge_starters_and_features(game_results_df, goalies_df, features_df, elo, feature_columns, goalie_feature_columns):
    goalies_df = goalies_df[goalies_df['TOI'] >=28.5]
    df = game_results_df.merge(goalies_df[goalie_feature_columns].add_prefix('home_'), left_on = 'Home_Team_Key', right_on = 'home_Team_Key', how = 'left').rename(columns ={'home_Name':'home_goalie'}).drop(columns = 'home_Team_Key')
    df = df.merge(goalies_df[goalie_feature_columns].add_prefix('away_'), left_on = 'Away_Team_Key', right_on = 'away_Team_Key', how = 'left').rename(columns ={'away_Name':'away_goalie'}).drop(columns = 'away_Team_Key')
    df = df.merge(features_df[feature_columns].add_prefix('home_'), left_on = 'Home_Team_Key', right_on = 'home_Team_Key', how = 'left')
    df = df.merge(features_df[feature_columns].add_prefix('away_'), left_on = 'Away_Team_Key', right_on = 'away_Team_Key', how = 'left')
    df = df.merge(elo[['elo_Team_Key', 'Rating.A.Pre']].add_prefix('home_'), left_on='Home_Team_Key', right_on='home_elo_Team_Key', how = 'left').drop(columns = 'home_elo_Team_Key')
    df = df.merge(elo[['elo_Team_Key', 'Rating.A.Pre']].add_prefix('away_'), left_on='Away_Team_Key', right_on='away_elo_Team_Key', how= 'left').drop(columns = 'away_elo_Team_Key')
    
    #categorize B2B
    conditions = [((df['home_B2B'] == 0) & (df['away_B2B'] == 0)),
                  ((df['home_B2B'] == 1) & (df['away_B2B'] == 0)),
                  ((df['home_B2B'] == 0) & (df['away_B2B'] == 1)),
                  ((df['home_B2B'] == 1) & (df['away_B2B'] == 1))
                 ]
    
    choices = ['Neither',
               'Home_only',
               'Away_only',
               'Both']

    df['B2B_Status'] = np.select(conditions, choices)
    
    
    #season
    conditions = [((df['date'] >= '2017-10-04') & (df['date'] <= '2018-04-08')),
                  ((df['date'] >= '2018-10-03') & (df['date'] <= '2019-04-06')),
                  ((df['date'] >= '2019-10-02') & (df['date'] <= '2020-03-12')),
                  ((df['date'] >= '2021-01-13') & (df['date'] <= '2021-06-29'))
                 ]
    
    choices = ['2017-2018',
               '2018-2019',
               '2019-2020',
               '2020-2021']

    df['Season'] = np.select(conditions, choices)

    return df

# %%
goalie_feature_columns = ['Team_Key', 'Name', 'Goalie_FenwickSV%', 'Goalie_GSAx/60', 'Goalie_HDCSV%']

# %% [markdown]
# ### Get ELO Data

# %%
elo = pd.read_csv('https://raw.githubusercontent.com/NeilPaine538/NHL-Player-And-Team-Ratings/master/nhl_elo_historical.csv')

# %%
elo = elo[elo['Date'] > '2013']

# %%
elo.head()
# Out:
#              Game.ID        Date  Year            Team.A Franch.A  \
# 104708  201300119BOS  2013-01-19  2013     Boston Bruins      BOS
# 104709  201300119BOS  2013-01-19  2013  New York Rangers      NYR
# 104710  201300119DAL  2013-01-19  2013      Dallas Stars      DAL
# 104711  201300119DAL  2013-01-19  2013   Phoenix Coyotes      ARI
# 104712  201300119FLA  2013-01-19  2013  Florida Panthers      FLA
#
#         Rating.A.Pre  Rating.A.Post  Goals.A               Team.B Franch.B  \
# 104708       1543.19        1546.31      3.0     New York Rangers      NYR
# 104709       1529.50        1526.38      1.0        Boston Bruins      BOS
# 104710       1497.23        1499.51      4.0      Phoenix Coyotes      ARI
# 104711       1528.15        1525.87      3.0         Dallas Stars      DAL
# 104712       1483.35        1487.87      5.0  Carolina Hurricanes      CAR
#
#         Rating.B.Pre  Rating.B.Post  Goals.B   OT  Playoff  Neutral  Home  \
# 104708       1529.50        1526.38      1.0  NaN        0        0     1
# 104709       1543.19        1546.31      3.0  NaN        0        0     0
# 104710       1528.15        1525.87      3.0  NaN        0        0     1
# 104711       1497.23        1499.51      4.0  NaN        0        0     0
# 104712       1487.70        1483.19      1.0  NaN        0        0     1
#
#         Win  Margin  Elo_diff  HomeIce Forecast  Delta  Multiplier   Shift
# 104708  1.0       2     63.69        1    59.1%  0.409      1.2682  3.1149
# 104709  0.0      -2    -63.69       -1    40.9% -0.409      1.2682 -3.1149
# 104710  1.0       1     19.08        1    52.7%  0.473      0.8048  2.2820
# 104711  0.0      -1    -19.08       -1    47.3% -0.473      0.8048 -2.2820
# 104712  1.0       4     45.65        1    56.5%  0.435      1.7317  4.5163

# %%
VGK                   144
N.J                   144
S.J                   143
T.B                   143
L.A                   141

# %%
elo_conversion = {'VEG' : 'VGK', 'NJD': 'N.J',  'SJS': 'S.J', 'TBL' : 'T.B',  'LAK' : 'L.A'}

# %%
elo = elo.replace({'Franch.A': elo_conversion})

# %%
elo.head()
# Out:
#              Game.ID        Date  Year            Team.A Franch.A  \
# 104708  201300119BOS  2013-01-19  2013     Boston Bruins      BOS
# 104709  201300119BOS  2013-01-19  2013  New York Rangers      NYR
# 104710  201300119DAL  2013-01-19  2013      Dallas Stars      DAL
# 104711  201300119DAL  2013-01-19  2013   Phoenix Coyotes      ARI
# 104712  201300119FLA  2013-01-19  2013  Florida Panthers      FLA
#
#         Rating.A.Pre  Rating.A.Post  Goals.A               Team.B Franch.B  \
# 104708       1543.19        1546.31      3.0     New York Rangers      NYR
# 104709       1529.50        1526.38      1.0        Boston Bruins      BOS
# 104710       1497.23        1499.51      4.0      Phoenix Coyotes      ARI
# 104711       1528.15        1525.87      3.0         Dallas Stars      DAL
# 104712       1483.35        1487.87      5.0  Carolina Hurricanes      CAR
#
#         Rating.B.Pre  Rating.B.Post  Goals.B   OT  Playoff  Neutral  Home  \
# 104708       1529.50        1526.38      1.0  NaN        0        0     1
# 104709       1543.19        1546.31      3.0  NaN        0        0     0
# 104710       1528.15        1525.87      3.0  NaN        0        0     1
# 104711       1497.23        1499.51      4.0  NaN        0        0     0
# 104712       1487.70        1483.19      1.0  NaN        0        0     1
#
#         Win  Margin  Elo_diff  HomeIce Forecast  Delta  Multiplier   Shift
# 104708  1.0       2     63.69        1    59.1%  0.409      1.2682  3.1149
# 104709  0.0      -2    -63.69       -1    40.9% -0.409      1.2682 -3.1149
# 104710  1.0       1     19.08        1    52.7%  0.473      0.8048  2.2820
# 104711  0.0      -1    -19.08       -1    47.3% -0.473      0.8048 -2.2820
# 104712  1.0       4     45.65        1    56.5%  0.435      1.7317  4.5163

# %%
elo['Franch.A'].value_counts()
# Out:
# PIT    766
# T.B    756
# BOS    752
# CHI    749
# WSH    747
# STL    746
# NYR    741
# S.J    741
# ANA    729
# NSH    728
# DAL    721
# NYI    716
# L.A    714
# MTL    714
# MIN    709
# COL    701
# CBJ    701
# OTT    700
# PHI    697
# DET    696
# TOR    695
# WPG    694
# CGY    691
# CAR    686
# VAN    684
# EDM    680
# ARI    673
# FLA    673
# N.J    668
# BUF    664
# VGK    334
# Name: Franch.A, dtype: int64

# %%
elo['elo_Team_Key'] = elo['Franch.A'].astype(str)+'_'+elo['Date'].astype(str)

# %% [markdown]
# ### Get Goalie Data

# %%
#import dictionary with goalie names and IDs from NHL API
infile = open("data/goalie_ids.pickle",'rb')
goalie_ids = pickle.load(infile)
infile.close()

# %%
## scrape season long stats to get name of all goalies who played in time frame
goalie_list = pd.read_html('https://www.naturalstattrick.com/playerteams.php?fromseason=20182019&thruseason=20202021&stype=2&sit=5v5&score=all&stdoi=g&rate=n&team=ALL&pos=S&loc=B&toi=0&gpfilt=none&fd=&td=&tgp=410&lines=single&draftteam=ALL')[0]

# %%
#find which goalies are missing from goalie_ids dictionary
missing_goalies2 = [g for g in list(goalie_list['Player']) if g not in goalie_ids.keys() ]

# %%
## Cal Petersen already in Data Dictionary as Calvin Petersen 
missing_goalies2.remove('Cal Petersen')

# %%
missing_goalies2
# Out:
# []

# %%
def goalie_features(df, rolling_games = 40):
    rolling_games = rolling_games
    min_games = 10
    df['Date'] = df['Game'].apply(lambda x: pd.to_datetime(x[0:10]))
    df['Team_Key'] = df['Team'].astype(str)+'_'+df['Date'].astype(str)
    
    df['Rolling_TOI'] = df.groupby('ID')['TOI'].transform(lambda x: x.rolling(rolling_games, min_games).sum().shift())
    df['Rolling_FA'] = df.groupby('ID')['FA'].transform(lambda x: x.rolling(rolling_games, min_games).sum().shift())
    df['Rolling_SA'] = df.groupby('ID')['SA'].transform(lambda x: x.rolling(rolling_games, min_games).sum().shift())
    df['Rolling_GA'] = df.groupby('ID')['GA'].transform(lambda x: x.rolling(rolling_games, min_games).sum().shift())
    df['Rolling_xGA'] = df.groupby('ID')['xGA'].transform(lambda x: x.rolling(rolling_games, min_games).sum().shift())
    df['Rolling_HDCA'] = df.groupby('ID')['HDCA'].transform(lambda x: x.rolling(rolling_games, min_games).sum().shift())
    df['Rolling_HDGA'] = df.groupby('ID')['HDGA'].transform(lambda x: x.rolling(rolling_games, min_games).sum().shift())
    
    df['Goalie_FenwickSV%'] =  (df['Rolling_FA'] - df['Rolling_GA']) /  df['Rolling_FA']
    df['Goalie_GSAx'] = df['Rolling_xGA'] - df['Rolling_GA']
    df['Goalie_GSAx/60'] =  df['Goalie_GSAx']*60 /  df['Rolling_TOI']
    df['Goalie_HDCSV%'] = (df['Rolling_HDCA'] - df['Rolling_HDGA'] ) / df['Rolling_HDCA'] 
    return df

# %%
# only use at most 2 seasons
def get_goalie_data(goalie_ids, start_year, end_year):
    counter = 0
    for name, gid in goalie_ids.items():

        sequence = [x/10 for x in range(60, 120)]
        time.sleep(random.choice(sequence))
        url = 'https://www.naturalstattrick.com/playerreport.php?fromseason={}&thruseason={}&playerid={}&sit=all&stype=2&stdoi=oi&rate=n&v=g'.format(start_year, end_year, gid)
        #due to number of http requests, NST may ban your IP before the loop finishes. I needed to use a VPN to get around this. If IP gets banned, this function will still return the current DF and you can call the function again and pass in an updated goalie dictionary to get the rest
        try:
            individual_df = pd.read_html(url)[0]
            individual_df['Name'] = name
            individual_df['ID'] = gid
        except:
            print(f'Ended before {name}')
            return all_goalies4 

        if counter == 0:
            all_goalies4 = individual_df
            print(name)
            print(counter)
        elif counter != 0:
            all_goalies4 = pd.concat([all_goalies4, individual_df])
            print(name)
            print(counter)


        counter +=1
    
    return all_goalies4

# %%
goalies_161718 = get_goalie_data(goalie_ids, 20162017, 20172018)
# Out:
# Scott Wedgewood
# 0
# Aaron Dell
# 1
# Mackenzie Blackwood
# 2
# Cory Schneider
# 3
# Semyon Varlamov
# 4
# Ilya Sorokin
# 5
# Keith Kinkaid
# 6
# Igor Shesterkin
# 7
# Alexandar Georgiev
# 8
# Brian Elliott
# 9
# Alex Lyon
# 10
# Carter Hart
# 11
# Emil Larmi
# 12
# Tristan Jarry
# 13
# Casey DeSmith
# 14
# Jaroslav Halak
# 15
# Tuukka Rask
# 16
# Michael Houser
# 17
# Ukko-Pekka Luukkonen
# 18
# Dustin Tokarski
# 19
# Carter Hutton
# 20
# Linus Ullmark
# 21
# Charlie Lindgren
# 22
# Carey Price
# 23
# Jake Allen
# 24
# Cayden Primeau
# 25
# Joey Daccord
# 26
# Anton Forsberg
# 27
# Matt Murray
# 28
# Marcus Hogberg
# 29
# Filip Gustavsson
# 30
# Frederik Andersen
# 31
# Jack Campbell
# 32
# David Rittich
# 33
# James Reimer
# 34
# Petr Mrazek
# 35
# Alex Nedeljkovic
# 36
# Philippe Desrosiers
# 37
# Sam Montembeault
# 38
# Sergei Bobrovsky
# 39
# Chris Driedger
# 40
# Spencer Knight
# 41
# Christopher Gibson
# 42
# Curtis McElhinney
# 43
# Andrei Vasilevskiy
# 44
# Craig Anderson
# 45
# Vitek Vanecek
# 46
# Ilya Samsonov
# 47
# Malcolm Subban
# 48
# Collin Delia
# 49
# Kevin Lankinen
# 50
# Thomas Greiss
# 51
# Jonathan Bernier
# 52
# Kasimir Kaskisuo
# 53
# Pekka Rinne
# 54
# Juuse Saros
# 55
# Jordan Binnington
# 56
# Ville Husso
# 57
# Artyom Zagidulin
# 58
# Jacob Markstrom
# 59
# Louis Domingue
# 60
# Pavel Francouz
# 61
# Adam Werner
# 62
# Peyton Jones
# 63
# Devan Dubnyk
# 64
# Philipp Grubauer
# 65
# Jonas Johansson
# 66
# Mike Smith
# 89
# Laurent Brossoit
# 90
# Connor Hellebuyck
# 91
# Darcy Kuemper
# 92
# Antti Raanta
# 93
# Adin Hill
# 94
# Marc-Andre Fleury
# 95
# Robin Lehner
# 96
# Adam Wilcox
# 97
# Al Montoya
# 98
# Anders Nilsson
# 99
# Antti Niemi
# 100
# Calvin Pickard
# 101
# Cam Ward
# 102
# Cameron Talbot
# 103
# Chad Johnson
# 104
# Corey Crawford
# 105
# Daniel Taylor
# 106
# Eddie Lack
# 107
# Eric Comrie
# 108
# Harri Sateri
# 109
# Henrik Lundqvist
# 110
# Jared Coreau
# 111
# Jean-Francois Berube
# 112
# Jeff Glass
# 113
# Jimmy Howard
# 114
# Jon Gillies
# 115
# Kari Lehtonen
# 116
# Ken Appleby
# 117
# Maxime Lagace
# 118
# Michael Hutchinson
# 119
# Michal Neuvirth
# 120
# Mike Condon
# 121
# Mike McKenna
# 122
# Ondrej Pavelec
# 123
# Oscar Dansk
# 124
# Peter Budaj
# 125
# Reto Berra
# 126
# Roberto Luongo
# 127
# Scott Darling
# 128
# Steve Mason
# 129
# Richard Bachman
# 130
# Edward Pasquale
# 131
# Garret Sparks
# 132
# Antoine Bibeau
# 133
# Pheonix Copley
# 134
# Dan Vladar
# 135
# Landon Bow
# 136
# David Ayres
# 137
# Kevin Boyle
# 138
# Stuart Skinner
# 139
# Hunter Miska
# 140
# Matiss Kivlenieks
# 141
# Gilles Senn
# 142
# Jeremy Swayman
# 143
# Logan Thompson
# 144
# Kaden Fulcher
# 145
# Veini Vehvilainen
# 146
# Ivan Prosvetov
# 147
# Alexei Melnichuk
# 148

# %%
goalies_2021.to_csv('data/goalie_logs_2021')

# %%
goalies_all_C = pd.concat([goalies_161718, goalies_181920, goalies_2021])

# %%
goalie_features_dfC = goalie_features(goalies_all_C)

# %%
goalie_features_dfC
# Out:
#                      Game Team        TOI  CF  CA    CF%  FF  FA    FF%  SF  \
# 0   2017-10-30 ARI at PHI  ARI  64.666667  58  60  49.15  42  48  46.67  33
# 1   2017-10-31 ARI at DET  ARI  58.333333  54  63  46.15  41  53  43.62  32
# 2   2017-11-06 ARI at WSH  ARI  63.883333  49  75  39.52  38  60  38.78  26
# 3   2017-11-14 ARI at WPG  ARI  34.866667  32  26  55.17  20  21  48.78  18
# 4   2017-11-22 S.J at ARI  ARI  44.333333  32  32     50  23  24  48.94  19
# ..                    ...  ...        ...  ..  ..    ...  ..  ..    ...  ..
# 0   2021-03-06 CBJ at DAL  CBJ  10.666667   5   6  45.45   3   5   37.5   3
# 0   2021-03-31 ARI at COL  ARI  53.633333  42  52  44.68  34  39  46.58  29
# 1   2021-04-09 ARI at VGK  ARI  18.416667  18  10  64.29  12   5  70.59   7
# 2   2021-04-12 ARI at COL  ARI  57.966667  58  51  53.21  47  32  59.49  33
# 0   2021-02-11 S.J at L.A  S.J   9.183333  10   6   62.5  10   6   62.5   7
#
#     SA    SF% GF GA    GF%   xGF   xGA   xGF% SCF SCA   SCF% SCGF SCGA  SCGF%  \
# 0   31  51.56  4  3  57.14  2.98  2.27  56.78  32  21  60.38    3    3     50
# 1   39  45.07  3  4  42.86  1.73  2.50     41  28  32  46.67    1    2  33.33
# 2   40  39.39  2  3     40  1.81  2.84  38.95  20  31  39.22    2    1  66.67
# 3   17  51.43  1  1     50  1.15  1.41     45  17  15  53.13    0    1      0
# 4   16  54.29  1  2  33.33  1.22  1.41  46.35  12  16  42.86    1    2  33.33
# ..  ..    ... .. ..    ...   ...   ...    ...  ..  ..    ...  ...  ...    ...
# 0    4  42.86  0  1      0  0.06  0.15  26.35   3   2     60    0    1      0
# 0   28  50.88  2  5  28.57  1.42  2.32  37.94  15  29  34.09    1    5  16.67
# 1    4  63.64  3  1     75  0.63  0.44  58.94  10   8  55.56    3    1     75
# 2   19  63.46  2  3     40  2.87  1.80  61.36  19  29  39.58    2    3     40
# 0    5  58.33  0  0      -  0.59  0.15  80.17   3   1     75    0    0      -
#
#    HDCF HDCA  HDCF% HDGF HDGA  HDGF% MDCF MDCA  MDCF% MDGF MDGA  MDGF% LDCF  \
# 0    13    8   61.9    1    2  33.33   19   13  59.38    2    1  66.67   18
# 1    11   15  42.31    1    1     50   17   17     50    0    1   0.00   24
# 2     8   10  44.44    2    1  66.67   12   21  36.36    0    0      -   26
# 3     5    7  41.67    0    1      0   12    8     60    0    0      -   14
# 4     8    7  53.33    1    2  33.33    4    9  30.77    0    0      -   15
# ..  ...  ...    ...  ...  ...    ...  ...  ...    ...  ...  ...    ...  ...
# 0     0    0      -    0    0      -    3    2     60    0    1      0    1
# 0     6   11  35.29    0    1      0    9   18  33.33    1    4     20   26
# 1     3    3     50    1    1     50    7    5  58.33    2    0    100    7
# 2     9    7  56.25    1    1     50   10   22  31.25    1    2  33.33   36
# 0     3    0    100    0    0      -    0    1      0    0    0      -    7
#
#    LDCA  LDCF% LDGF LDGA   LDGF% On-Ice SH% On-Ice SV%    PDO  \
# 0    35  33.96    1    0  100.00      12.12      90.32  1.024
# 1    29  45.28    2    2   50.00       9.38      89.74  0.991
# 2    37  41.27    0    2    0.00       7.69       92.5  1.002
# 3     9  60.87    1    0  100.00       5.56      94.12  0.997
# 4    15     50    0    0       -       5.26       87.5  0.928
# ..  ...    ...  ...  ...     ...        ...        ...    ...
# 0     3     25    0    0       -          0         75   0.75
# 0    21  55.32    1    0  100.00        6.9      82.14   0.89
# 1     0    100    0    0       -      42.86         75  1.179
# 2    21  63.16    0    0       -       6.06      84.21  0.903
# 0     2  77.78    0    0       -          0        100      1
#
#    Off. Zone Starts Neu. Zone Starts Def. Zone Starts On The Fly Starts  \
# 0                 1                4                0                 0
# 1                 1                4                0                 0
# 2                 1                4                0                 0
# 3                 0                2                0                 0
# 4                 0                3                1                 0
# ..              ...              ...              ...               ...
# 0                 1                1                0                 0
# 0                 1                3                0                 0
# 1                 0                2                0                 0
# 2                 0                4                0                 0
# 0                 0                1                0                 0
#
#    Off. Zone Start % Off. Zone Faceoffs Neu. Zone Faceoffs Def. Zone Faceoffs  \
# 0             100.00                 24                 23                 25
# 1             100.00                 18                 22                 24
# 2             100.00                 14                 18                 26
# 3                  -                 10                 14                  7
# 4               0.00                  9                 13                 22
# ..               ...                ...                ...                ...
# 0                100                  2                  5                  4
# 0             100.00                 22                 18                 12
# 1                  -                  5                 10                  2
# 2                  -                 18                 18                 22
# 0                  -                  3                  2                  0
#
#    Off. Zone Faceoff %               Name       ID       Date        Team_Key  \
# 0                48.98    Scott Wedgewood  8475809 2017-10-30  ARI_2017-10-30
# 1                42.86    Scott Wedgewood  8475809 2017-10-31  ARI_2017-10-31
# 2                   35    Scott Wedgewood  8475809 2017-11-06  ARI_2017-11-06
# 3                58.82    Scott Wedgewood  8475809 2017-11-14  ARI_2017-11-14
# 4                29.03    Scott Wedgewood  8475809 2017-11-22  ARI_2017-11-22
# ..                 ...                ...      ...        ...             ...
# 0                33.33  Veini Vehvilainen  8481001 2021-03-06  CBJ_2021-03-06
# 0                64.71     Ivan Prosvetov  8481031 2021-03-31  ARI_2021-03-31
# 1                71.43     Ivan Prosvetov  8481031 2021-04-09  ARI_2021-04-09
# 2                   45     Ivan Prosvetov  8481031 2021-04-12  ARI_2021-04-12
# 0                  100   Alexei Melnichuk  8482246 2021-02-11  S.J_2021-02-11
#
#     Rolling_TOI  Rolling_FA  Rolling_SA  Rolling_GA  Rolling_xGA  \
# 0           NaN         NaN         NaN         NaN          NaN
# 1           NaN         NaN         NaN         NaN          NaN
# 2           NaN         NaN         NaN         NaN          NaN
# 3           NaN         NaN         NaN         NaN          NaN
# 4           NaN         NaN         NaN         NaN          NaN
# ..          ...         ...         ...         ...          ...
# 0           NaN         NaN         NaN         NaN          NaN
# 0           NaN         NaN         NaN         NaN          NaN
# 1           NaN         NaN         NaN         NaN          NaN
# 2           NaN         NaN         NaN         NaN          NaN
# 0           NaN         NaN         NaN         NaN          NaN
#
#     Rolling_HDCA  Rolling_HDGA  Goalie_FenwickSV%  Goalie_GSAx  \
# 0            NaN           NaN                NaN          NaN
# 1            NaN           NaN                NaN          NaN
# 2            NaN           NaN                NaN          NaN
# 3            NaN           NaN                NaN          NaN
# 4            NaN           NaN                NaN          NaN
# ..           ...           ...                ...          ...
# 0            NaN           NaN                NaN          NaN
# 0            NaN           NaN                NaN          NaN
# 1            NaN           NaN                NaN          NaN
# 2            NaN           NaN                NaN          NaN
# 0            NaN           NaN                NaN          NaN
#
#     Goalie_GSAx/60  Goalie_HDCSV%
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ..             ...            ...
# 0              NaN            NaN
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 0              NaN            NaN
#
# [12362 rows x 69 columns]

# %%
goalie_features_dfC.to_csv('data/goalie_game_logs_C.csv')

# %%
#older version of the df
goalie_features_dfB = pd.read_csv('goalie_game_logs.csv', low_memory=False)

# %%
goalie_features_dfB = goalie_features(goalie_features_dfB)

# %% [markdown]
# #### Goalie GAR

# %%
gar = pd.read_csv('https://raw.githubusercontent.com/NeilPaine538/NHL-Player-And-Team-Ratings/master/gar-data-historical.csv', encoding = "ISO-8859-1" )

# %%
gar = gar[gar['pos'] == 'G']
gar = gar[gar['year_id'] > 2010]
gar.head()
# Out:
#     player_id      player_name  year_id  age team_id type  stint_id  \
# 2   stolaan01  Anthony Stolarz     2021   27     ANA   RS         1
# 8   gibsojo02      John Gibson     2021   27     ANA   RS         1
# 35  millery01      Ryan Miller     2021   40     ANA   RS         1
# 42   hillad01        Adin Hill     2021   24     ARI   RS         1
# 46  kuempda01    Darcy Kuemper     2021   30     ARI   RS         1
#
#           team_name franch_id lg_id pos maj_pos  GP   G   A  Pts  GC/G  +/-  \
# 2     Anaheim Ducks       ANA   NHL   G       G NaN NaN NaN  NaN   NaN  NaN
# 8     Anaheim Ducks       ANA   NHL   G       G NaN NaN NaN  NaN   NaN  NaN
# 35    Anaheim Ducks       ANA   NHL   G       G NaN NaN NaN  NaN   NaN  NaN
# 42  Arizona Coyotes       PHX   NHL   G       G NaN NaN NaN  NaN   NaN  NaN
# 46  Arizona Coyotes       PHX   NHL   G       G NaN NaN NaN  NaN   NaN  NaN
#
#     PIM  TOI  ATOI   S  SPG  S%  Adj CFrel  GP_G   Min_G  GA_G    SA_G    SV%  \
# 2   NaN  NaN   NaN NaN  NaN NaN        NaN   8.0   464.0  17.0   230.0  0.926
# 8   NaN  NaN   NaN NaN  NaN NaN        NaN  34.0  1970.0  97.0  1006.0  0.904
# 35  NaN  NaN   NaN NaN  NaN NaN        NaN  15.0   809.0  47.0   407.0  0.885
# 42  NaN  NaN   NaN NaN  NaN NaN        NaN  18.0   943.0  42.0   482.0  0.913
# 46  NaN  NaN   NaN NaN  NaN NaN        NaN  26.0  1487.0  64.0   682.0  0.906
#
#     OPS  DPS  GPS   PS  Offense  Defense  Goalie  Total GAR  Tm Sched  \
# 2   0.0  0.0  1.8  1.8      0.0      0.0     4.2        4.2      54.0
# 8   0.0  0.0  5.4  5.4      0.0      0.0     1.7        1.7      54.0
# 35  0.0  0.0  1.3  1.3      0.0      0.0    -5.3       -5.3      54.0
# 42  0.0  0.0  3.1  3.1      0.0      0.0     4.3        4.3      54.0
# 46  0.0  0.0  3.8  3.8      0.0      0.0     2.1        2.1      54.0
#
#     Roster Sz  Adj. Off  Adj. Def  Adj. Gltd  Adj. GAR Prev Tm  Arrived  \
# 2        18.0       0.0       0.0        6.4       6.4     EDM     2020
# 8        18.0       0.0       0.0        2.6       2.6     ---     2014
# 35       18.0       0.0       0.0       -8.0      -8.0     VAN     2018
# 42       18.0       0.0       0.0        6.5       6.5     ---     2018
# 46       18.0       0.0       0.0        3.2       3.2     LAK     2018
#
#     Departed Next Tm
# 2       2021     ---
# 8       2021     ---
# 35      2021     ---
# 42      2021     ---
# 46      2021     ---

# %%
gar['year_id'].value_counts()
# Out:
# 2014    137
# 2020    132
# 2018    131
# 2019    122
# 2017    122
# 2016    122
# 2015    122
# 2011    116
# 2012    111
# 2013    107
# 2021     98
# Name: year_id, dtype: int64

# %% [markdown]
# ### Determine Goalie Stats to Impute for Goalies Having Player Less Than 10 Games

# %%
goalie_features_dfC.isna().sum()
# Out:
# Game                    0
# Team                    0
# TOI                     0
# CF                      0
# CA                      0
#                      ...
# Rolling_HDGA         1231
# Goalie_FenwickSV%    1231
# Goalie_GSAx          1231
# Goalie_GSAx/60       1231
# Goalie_HDCSV%        1231
# Length: 69, dtype: int64

# %%
#set df for goalies who hadnt played 10 games at that point
ig_df = goalie_features_dfC[(goalie_features_dfC['Goalie_FenwickSV%'].isna()) & (goalie_features_dfC['Date'] >= '2017-10-04') & (goalie_features_dfC['Date']<'2021')]

# %%
ig_df[ig_df['Date'].apply(lambda x: x.year) == 2021]
# Out:
# Empty DataFrame
# Columns: [Game, Team, TOI, CF, CA, CF%, FF, FA, FF%, SF, SA, SF%, GF, GA, GF%, xGF, xGA, xGF%, SCF, SCA, SCF%, SCGF, SCGA, SCGF%, HDCF, HDCA, HDCF%, HDGF, HDGA, HDGF%, MDCF, MDCA, MDCF%, MDGF, MDGA, MDGF%, LDCF, LDCA, LDCF%, LDGF, LDGA, LDGF%, On-Ice SH%, On-Ice SV%, PDO, Off. Zone Starts, Neu. Zone Starts, Def. Zone Starts, On The Fly Starts, Off. Zone Start %, Off. Zone Faceoffs, Neu. Zone Faceoffs, Def. Zone Faceoffs, Off. Zone Faceoff %, Name, ID, Date, Team_Key, Rolling_TOI, Rolling_FA, Rolling_SA, Rolling_GA, Rolling_xGA, Rolling_HDCA, Rolling_HDGA, Goalie_FenwickSV%, Goalie_GSAx, Goalie_GSAx/60, Goalie_HDCSV%]
# Index: []

# %%
ig_TOI = ig_df['TOI'].sum()
ig_FA = ig_df['FA'].sum()
ig_GA = ig_df['GA'].sum()
ig_xGA = ig_df['xGA'].sum()
ig_HDCA = ig_df['HDCA'].sum()
ig_HDGA = ig_df['HDGA'].sum()

# %%
ig_FenwickSV = (ig_FA - ig_GA) /ig_FA
ig_GSAx = ig_xGA - ig_GA
ig_GSAx60 = (ig_GSAx*60) / ig_TOI
ig_HDCSV = (ig_HDCA - ig_HDGA )/ ig_HDCA

# %%
#experience goalie df for comparison
eg_df = goalie_features_dfC[(~goalie_features_dfC['Goalie_FenwickSV%'].isna()) & (goalie_features_dfC['Date'] >= '2017-10-04') & (goalie_features_dfC['Date']<'2021')]

# %%
eg_TOI = eg_df['TOI'].sum()
eg_FA = eg_df['FA'].sum()
eg_GA = eg_df['GA'].sum()
eg_xGA = eg_df['xGA'].sum()
eg_HDCA = eg_df['HDCA'].sum()
eg_HDGA = eg_df['HDGA'].sum()
eg_FenwickSV = (eg_FA - eg_GA) /eg_FA
eg_GSAx = eg_xGA - eg_GA
eg_GSAx60 = (eg_GSAx*60) / eg_TOI
eg_HDCSV = (eg_HDCA - eg_HDGA )/ eg_HDCA

# %%
display(ig_FenwickSV)
display(eg_FenwickSV)
# Out:
# 0.9350856996674342
# 0.9349842445976769

# %%
display(ig_GSAx60)
display(eg_GSAx60)
# Out:
# -0.2556941982582863
# -0.22348016885706548

# %%
goalie_features_dfB['Goalie_GSAx/60'].std()
# Out:
# 0.36999829059900696

# %%
display(ig_HDCSV )
display(eg_HDCSV)
# Out:
# 0.8620604259534423
# 0.8628162509198873

# %%
ig = [ig_FenwickSV,
ig_GSAx ,
ig_GSAx60 ,
ig_HDCSV ]

# %%
pickle_out = open("data/inexperienced_goalie_imputes.pickle","wb")
pickle.dump(ig, pickle_out)
pickle_out.close()

# %% [markdown]
# ### Original Scrape - No SVA

# %% [markdown]
# #### 2017-2018 Season

# %%
primary1718 = get_and_format_nst_team_stats('20172018','5v5', 'n')
pp1718 = get_and_format_nst_team_stats('20172018','pp', 'n')
pk1718 = get_and_format_nst_team_stats('20172018','pk', 'n')

# %%
features1718 = merge_team_stats(primary1718 ,pp1718 ,pk1718  )

features1718 = calculate_team_features(features1718 )

# %%
features1718.tail()
# Out:
#                                   Game Team                 Unnamed: 2  \
# 2537  2018-04-07 - Canucks 2, Oilers 3  VAN  Limited ReportFull Report
# 2538     2018-04-07 - Stars 4, Kings 2  DAL  Limited ReportFull Report
# 2539     2018-04-07 - Stars 4, Kings 2  L.A  Limited ReportFull Report
# 2540     2018-04-07 - Wild 6, Sharks 3  MIN  Limited ReportFull Report
# 2541     2018-04-07 - Wild 6, Sharks 3  S.J  Limited ReportFull Report
#
#             TOI  CF  CA    CF%  FF  FA    FF%  SF  SA    SF%  GF  GA     GF%  \
# 2537  51.583333  52  54  49.06  44  40  52.38  32  28  53.33   2   0  100.00
# 2538  50.700000  28  56  33.33  24  44  35.29  16  35  31.37   4   2   66.67
# 2539  50.700000  56  28  66.67  44  24  64.71  35  16  68.63   2   4   33.33
# 2540  53.466667  52  56  48.15  31  37  45.59  23  22  51.11   5   2   71.43
# 2541  53.466667  56  52  51.85  37  31  54.41  22  23  48.89   2   5   28.57
#
#        xGF   xGA   xGF%  SCF  SCA   SCF%  HDCF  HDCA  HDCF%  HDSF  HDSA  \
# 2537  2.73  2.99  47.71   28   32  46.67    15    16  48.39    12     9
# 2538  2.15  1.75  55.18   22   21  51.16     9     5  64.29     9     5
# 2539  1.75  2.15  44.82   21   22  48.84     5     9  35.71     5     9
# 2540  1.84  1.53  54.62   25   21  54.35    14    10  58.33    12     6
# 2541  1.53  1.84  45.38   21   25  45.65    10    14  41.67     6    12
#
#       HDSF%  HDGF  HDGA  HDGF%  HDSH%   HDSV%  MDCF  MDCA  MDCF%  MDSF  MDSA  \
# 2537  57.14     2     0  100.0  16.67  100.00    13    16  44.83     6    12
# 2538  64.29     3     1   75.0  33.33   80.00    13    16  44.83     4     7
# 2539  35.71     1     3   25.0  20.00   66.67    16    13  55.17     7     4
# 2540  66.67     3     2   60.0  25.00   66.67    11    11  50.00     4     4
# 2541  33.33     2     3   40.0  33.33   75.00    11    11  50.00     4     4
#
#       MDSF%  MDGF  MDGA  MDGF%  MDSH%  MDSV%  LDCF  LDCA  LDCF%  LDSF  LDSA  \
# 2537  33.33     0     0    NaN    0.0  100.0    22    16  57.89    12     5
# 2538  36.36     1     0  100.0   25.0  100.0     5    32  13.51     2    21
# 2539  63.64     0     1    0.0    0.0   75.0    32     5  86.49    21     2
# 2540  50.00     1     0  100.0   25.0  100.0    22    27  44.90     7    12
# 2541  50.00     0     1    0.0    0.0   75.0    27    22  55.10    12     7
#
#       LDSF%  LDGF  LDGA  LDGF%  LDSH%   LDSV%    SH%     SV%    PDO  \
# 2537  70.59     0     0    NaN   0.00  100.00   6.25  100.00  1.063
# 2538   8.70     0     1    0.0   0.00   95.24  25.00   94.29  1.193
# 2539  91.30     1     0  100.0   4.76  100.00   5.71   75.00  0.807
# 2540  36.84     1     0  100.0  14.29  100.00  21.74   90.91  1.126
# 2541  63.16     0     1    0.0   0.00   85.71   9.09   78.26  0.874
#
#       Attendance       Date  Game_Number        Team_Key    TOI_pk  xGA_pk  \
# 2537       18347 2018-04-07           82  VAN_2018-04-07  1.516667    0.31
# 2538       18230 2018-04-07           82  DAL_2018-04-07  6.000000    0.14
# 2539       18230 2018-04-07           82  L.A_2018-04-07  2.000000    0.17
# 2540       17562 2018-04-07           82  MIN_2018-04-07  3.250000    0.28
# 2541       17562 2018-04-07           82  S.J_2018-04-07  1.250000    0.00
#
#         TOI_pp  xGF_pp  sum_rolling20_TOI_5v5  sum_rolling20_FF_5v5  \
# 2537  4.966667    0.44             997.166667                 676.0
# 2538  2.000000    0.17             958.366667                 632.0
# 2539  6.000000    0.14             982.116667                 679.0
# 2540  1.250000    0.00             976.766667                 677.0
# 2541  3.250000    0.28            1017.316667                 757.0
#
#       sum_rolling20_FA_5v5  sum_rolling20_GF_5v5  sum_rolling20_GA_5v5  \
# 2537                 727.0                  32.0                  40.0
# 2538                 643.0                  27.0                  33.0
# 2539                 688.0                  41.0                  35.0
# 2540                 660.0                  37.0                  34.0
# 2541                 711.0                  49.0                  39.0
#
#       sum_rolling20_xGF_5v5  sum_rolling20_xGA_5v5  sum_rolling20_SF_5v5  \
# 2537                  34.26                  39.28                 480.0
# 2538                  34.14                  32.47                 445.0
# 2539                  32.65                  35.32                 481.0
# 2540                  36.27                  30.75                 492.0
# 2541                  42.40                  36.63                 546.0
#
#       last_20_FF%_5v5  last_20_GF%_5v5  last_20_xGF%_5v5  last_20_SH%  \
# 2537        48.182466        44.444444         46.586891     6.666667
# 2538        49.568627        45.000000         51.253566     6.067416
# 2539        49.670812        53.947368         48.035898     8.523909
# 2540        50.635752        52.112676         54.118174     7.520325
# 2541        51.566757        55.681818         53.650512     8.974359
#
#       sum_rolling20_TOI_pp  sum_rolling20_xGF_pp  last20_pp_TOI_per_game  \
# 2537             69.000000                  8.72                3.450000
# 2538             94.066667                 11.12                4.703333
# 2539             92.366667                 13.04                4.618333
# 2540             90.283333                 11.47                4.514167
# 2541             85.300000                 12.47                4.265000
#
#       last20_xGF_per_min_pp  sum_rolling20_TOI_pk  sum_rolling20_xGA_pk  \
# 2537               0.126377            105.366667                  9.51
# 2538               0.118214            108.033333                 14.14
# 2539               0.141176             94.516667                  9.07
# 2540               0.127044             88.000000                  7.56
# 2541               0.146190             68.700000                  7.74
#
#       last20_pk_TOI_per_game  last20_xGA_per_min_pk Last_Game_Date  \
# 2537                5.268333               0.090256     2018-04-05
# 2538                5.401667               0.130886     2018-04-06
# 2539                4.725833               0.095962     2018-04-05
# 2540                4.400000               0.085909     2018-04-05
# 2541                3.435000               0.112664     2018-04-05
# 1258                    0.146248                     4.822500
# 1259                    0.121208                     4.438333
# 1260                    0.103863                     3.874167
# 1261                    0.130532                     4.210000
# 1262                    0.109610                     5.315000
# 1263                    0.087868                     4.741667
# 1264                    0.117111                     4.317500
# 1265                    0.074431                     3.243333
# 1266                    0.136774                     5.145833
# 1267                    0.126377                     5.268333
# 1268                    0.118214                     5.401667
# 1269                    0.127044                     4.400000
# 1270                    0.156232                     5.039167
#
#       away_last20_xGA_per_min_pk  away_B2B
# 1241                    0.104317         0
# 1242                    0.115436         0
# 1243                    0.127405         0
# 1244                    0.153968         0
# 1245                    0.096578         0
# 1246                    0.106634         0
# 1247                    0.115555         0
# 1248                    0.163390         0
# 1249                    0.085022         1
# 1250                    0.116168         0
# 1251                    0.095727         0
# 1252                    0.144026         0
# 1253                    0.099417         0
# 1254                    0.127653         0
# 1255                    0.126267         0
# 1256                    0.149792         1
# 1257                    0.090953         1
# 1258                    0.149093         0
# 1259                    0.140819         0
# 1260                    0.127769         1
# 1261                    0.117815         0
# 1262                    0.120414         1
# 1263                    0.115044         0
# 1264                    0.124378         1
# 1265                    0.100822         1
# 1266                    0.118640         0
# 1267                    0.090256         0
# 1268                    0.130886         1
# 1269                    0.085909         0
# 1270                    0.147048         0

# %%
df_20172018.isna().sum()
# Out:
# game_id                          0
# date                             0
# venue                            0
# home_team                        0
# away_team                        0
# start_time                       0
# home_score                       0
# away_score                       0
# status                           0
# Home_Team_Won                    0
# Home_Team_Key                    0
# Away_Team_Key                    0
# home_goalie                      0
# home_Last_20_FenwickSV%        126
# home_Last_20_GSAx/60           126
# home_Last_20_HDCSV%            126
# away_goalie                      0
# away_Last_20_FenwickSV%        162
# away_Last_20_GSAx/60           162
# away_Last_20_HDCSV%            162
# home_Team_Key                    0
# home_last_20_FF%_5v5           329
# home_last_20_GF%_5v5           329
# home_last_20_xGF%_5v5          329
# home_last_20_SH%               329
# home_last20_pp_TOI_per_game    329
# home_last20_xGF_per_min_pp     329
# home_last20_pk_TOI_per_game    329
# home_last20_xGA_per_min_pk     329
# home_B2B                         0
# away_Team_Key                    0
# away_last_20_FF%_5v5           331
# away_last_20_GF%_5v5           331
# away_last_20_xGF%_5v5          331
# away_last_20_SH%               331
# away_last20_pp_TOI_per_game    331
# away_last20_xGF_per_min_pp     331
# away_last20_pk_TOI_per_game    331
# away_last20_xGA_per_min_pk     331
# away_B2B                         0
# dtype: int64

# %% [markdown]
# #### 2018-2019 Season

# %%
primary1819 = get_and_format_nst_team_stats('20182019','5v5', 'n')
pp1819 = get_and_format_nst_team_stats('20182019','pp', 'n')
pk1819 = get_and_format_nst_team_stats('20182019','pk', 'n')

# %%
features1819 = merge_team_stats(primary1819,pp1819,pk1819)

# %%
features1819 = calculate_team_features(features1819)

# %%
results1819 = get_game_results('2018-10-03', '2019-04-06')
# Out:
# Scraping the schedule between 2018-10-03 and 2019-04-06

# %%
df_20182019 = merge_starters_and_features(results1819, goalie_features_dfB , features1819, feature_columns, goalie_feature_columns)

# %%
df_20182019.tail()
# Out:
#          game_id        date                     venue home_team away_team  \
# 1318  2018021267  2019-04-06  American Airlines Center       DAL       MIN
# 1319  2018021269  2019-04-06          Gila River Arena       ARI       WPG
# 1320  2018021268  2019-04-06     Scotiabank Saddledome       CGY       EDM
# 1321  2018021270  2019-04-06            STAPLES Center       L.A       VGK
# 1322  2018021271  2019-04-06    SAP Center at San Jose       S.J       COL
#
#               start_time  home_score  away_score status  Home_Team_Won  \
# 1318 2019-04-07 00:00:00           3           0  Final              1
# 1319 2019-04-07 02:00:00           2           4  Final              0
# 1320 2019-04-07 02:00:00           1           3  Final              0
# 1321 2019-04-07 02:30:00           5           2  Final              1
# 1322 2019-04-07 02:30:00           5           2  Final              1
#
#        Home_Team_Key   Away_Team_Key     home_goalie  home_Last_20_FenwickSV%  \
# 1318  DAL_2019-04-06  MIN_2019-04-06      Ben Bishop                 0.958922
# 1319  ARI_2019-04-06  WPG_2019-04-06  Calvin Pickard                 0.908805
# 1320  CGY_2019-04-06  EDM_2019-04-06      Mike Smith                 0.935829
# 1321  L.A_2019-04-06  VGK_2019-04-06  Jonathan Quick                 0.907407
# 1322  S.J_2019-04-06  COL_2019-04-06    Martin Jones                 0.921196
#
#       home_Last_20_GSAx/60  home_Last_20_HDCSV%        away_goalie  \
# 1318              0.689728             0.923077       Alex Stalock
# 1319             -1.222352             0.811429  Connor Hellebuyck
# 1320              0.043749             0.890995     Mikko Koskinen
# 1321             -1.504394             0.823834  Marc-Andre Fleury
# 1322             -0.641724             0.822660    Semyon Varlamov
#
#       away_Last_20_FenwickSV%  away_Last_20_GSAx/60  away_Last_20_HDCSV%  \
# 1318                 0.927746             -0.614854             0.808219
# 1319                 0.937294             -0.151051             0.866071
# 1320                 0.929716             -0.480499             0.869565
# 1321                 0.936629              0.047983             0.833333
# 1322                 0.932530             -0.217921             0.861607
#
#        home_Team_Key  home_last_20_FF%_5v5  home_last_20_GF%_5v5  \
# 1318  DAL_2019-04-06             49.125364             54.098361
# 1319  ARI_2019-04-06             49.018182             56.140351
# 1320  CGY_2019-04-06             56.752768             61.363636
# 1321  L.A_2019-04-06             46.001367             39.784946
# 1322  S.J_2019-04-06             53.209590             46.590909
#
#       home_last_20_xGF%_5v5  home_last_20_SH%  home_last20_pp_TOI_per_game  \
# 1318              52.671958          6.470588                     4.323333
# 1319              51.445636          6.543967                     5.610000
# 1320              57.474336          9.782609                     5.120000
# 1321              47.427932          8.078603                     4.222500
# 1322              53.004873          8.418891                     4.920833
#
#       home_last20_xGF_per_min_pp  home_last20_pk_TOI_per_game  \
# 1318                    0.120625                     4.574167
# 1319                    0.112121                     4.285000
# 1320                    0.092480                     4.489167
# 1321                    0.129070                     4.032500
# 1322                    0.124776                     4.365000
#
#       home_last20_xGA_per_min_pk  home_B2B   away_Team_Key  \
# 1318                    0.121880       1.0  MIN_2019-04-06
# 1319                    0.102917       0.0  WPG_2019-04-06
# 1320                    0.123408       0.0  EDM_2019-04-06
# 1321                    0.125728       1.0  VGK_2019-04-06
# 1322                    0.118442       0.0  COL_2019-04-06
#
#       away_last_20_FF%_5v5  away_last_20_GF%_5v5  away_last_20_xGF%_5v5  \
# 1318             49.752999             45.161290              52.003938
# 1319             46.690647             50.000000              43.688785
# 1320             45.687812             44.943820              44.327894
# 1321             55.547898             58.823529              56.390790
# 1322             49.443207             50.000000              49.039005
#
#       away_last_20_SH%  away_last20_pp_TOI_per_game  \
# 1318          5.645161                     5.189167
# 1319          8.510638                     5.008333
# 1320          8.350731                     3.325833
# 1321          8.605852                     3.981667
# 1322          6.150794                     5.243333
#
#       away_last20_xGF_per_min_pp  away_last20_pk_TOI_per_game  \
# 1318                    0.097318                     4.146667
# 1319                    0.147854                     4.606667
# 1320                    0.104635                     4.376667
# 1321                    0.135245                     4.005000
# 1322                    0.101271                     4.666667
#
#       away_last20_xGA_per_min_pk  away_B2B
# 1318                    0.082838       0.0
# 1319                    0.113097       0.0
# 1320                    0.118812       0.0
# 1321                    0.103620       0.0
# 1322                    0.136821       0.0

# %%
df_20182019.isna().sum()
# Out:
# game_id                          0
# date                             0
# venue                            0
# home_team                        0
# away_team                        0
# start_time                       0
# home_score                       0
# away_score                       0
# status                           0
# Home_Team_Won                    0
# Home_Team_Key                    0
# Away_Team_Key                    0
# home_goalie                      1
# home_Last_20_FenwickSV%        119
# home_Last_20_GSAx/60           119
# home_Last_20_HDCSV%            119
# away_goalie                      2
# away_Last_20_FenwickSV%        137
# away_Last_20_GSAx/60           137
# away_Last_20_HDCSV%            137
# home_Team_Key                    1
# home_last_20_FF%_5v5           328
# home_last_20_GF%_5v5           328
# home_last_20_xGF%_5v5          328
# home_last_20_SH%               328
# home_last20_pp_TOI_per_game    328
# home_last20_xGF_per_min_pp     328
# home_last20_pk_TOI_per_game    328
# home_last20_xGA_per_min_pk     328
# home_B2B                         1
# away_Team_Key                    1
# away_last_20_FF%_5v5           332
# away_last_20_GF%_5v5           332
# away_last_20_xGF%_5v5          332
# away_last_20_SH%               332
# away_last20_pp_TOI_per_game    332
# away_last20_xGF_per_min_pp     332
# away_last20_pk_TOI_per_game    332
# away_last20_xGA_per_min_pk     332
# away_B2B                         1
# dtype: int64

# %% [markdown]
# #### 2019-2020 Season

# %%
primary1920 = get_and_format_nst_team_stats('20192020','5v5', 'n')
pp1920 = get_and_format_nst_team_stats('20192020','pp', 'n')
pk1920 = get_and_format_nst_team_stats('20192020','pk', 'n')

# %%
features1920 = merge_team_stats(primary1920,pp1920,pk1920)

# %%
features1920 = calculate_team_features(features1920)

# %%
results1920 = get_game_results('2019-10-02', '2020-03-12')
# Out:
# Scraping the schedule between 2019-10-02 and 2020-03-12

# %%
df_20192020 = merge_starters_and_features(results1920, goalie_features_dfB , features1920, feature_columns, goalie_feature_columns)

# %%
df_20192020.isna().sum()
# Out:
# game_id                          0
# date                             0
# venue                            0
# home_team                        0
# away_team                        0
# start_time                       0
# home_score                       0
# away_score                       0
# status                           0
# Home_Team_Won                    0
# Home_Team_Key                    0
# Away_Team_Key                    0
# home_goalie                      1
# home_Last_20_FenwickSV%         78
# home_Last_20_GSAx/60            78
# home_Last_20_HDCSV%             78
# away_goalie                      2
# away_Last_20_FenwickSV%         82
# away_Last_20_GSAx/60            82
# away_Last_20_HDCSV%             82
# home_Team_Key                    1
# home_last_20_FF%_5v5           320
# home_last_20_GF%_5v5           320
# home_last_20_xGF%_5v5          320
# home_last_20_SH%               320
# home_last20_pp_TOI_per_game    320
# home_last20_xGF_per_min_pp     320
# home_last20_pk_TOI_per_game    320
# home_last20_xGA_per_min_pk     320
# home_B2B                         1
# away_Team_Key                    1
# away_last_20_FF%_5v5           320
# away_last_20_GF%_5v5           320
# away_last_20_xGF%_5v5          320
# away_last_20_SH%               320
# away_last20_pp_TOI_per_game    320
# away_last20_xGF_per_min_pp     320
# away_last20_pk_TOI_per_game    320
# away_last20_xGA_per_min_pk     320
# away_B2B                         1
# dtype: int64

# %%
df_20192020[df_20192020['home_Team_Key'].isna()]
# Out:
#         game_id        date              venue           home_team  \
# 792  2019120001  2020-01-24  Enterprise Center  AMERICAN ALL-STARS
#
#               away_team          start_time  home_score  away_score status  \
# 792  CANADIAN ALL-STARS 2020-01-25 02:30:00           1           2  Final
#
#      Home_Team_Won                  Home_Team_Key  \
# 792              0  AMERICAN ALL-STARS_2020-01-24
#
#                      Away_Team_Key home_goalie  home_Last_20_FenwickSV%  \
# 792  CANADIAN ALL-STARS_2020-01-24         NaN                      NaN
#
#      home_Last_20_GSAx/60  home_Last_20_HDCSV% away_goalie  \
# 792                   NaN                  NaN         NaN
#
#      away_Last_20_FenwickSV%  away_Last_20_GSAx/60  away_Last_20_HDCSV%  \
# 792                      NaN                   NaN                  NaN
#
#     home_Team_Key  home_last_20_FF%_5v5  home_last_20_GF%_5v5  \
# 792           NaN                   NaN                   NaN
#
#      home_last_20_xGF%_5v5  home_last_20_SH%  home_last20_pp_TOI_per_game  \
# 792                    NaN               NaN                          NaN
#
#      home_last20_xGF_per_min_pp  home_last20_pk_TOI_per_game  \
# 792                         NaN                          NaN
#
#      home_last20_xGA_per_min_pk  home_B2B away_Team_Key  away_last_20_FF%_5v5  \
# 792                         NaN       NaN           NaN                   NaN
#
#      away_last_20_GF%_5v5  away_last_20_xGF%_5v5  away_last_20_SH%  \
# 792                   NaN                    NaN               NaN
#
#      away_last20_pp_TOI_per_game  away_last20_xGF_per_min_pp  \
# 792                          NaN                         NaN
#
#      away_last20_pk_TOI_per_game  away_last20_xGA_per_min_pk  away_B2B
# 792                          NaN                         NaN       NaN

# %% [markdown]
# #### 2020-2021 Season

# %%
primary2021 = get_and_format_nst_team_stats('20202021','5v5', 'n')
pp2021 = get_and_format_nst_team_stats('20202021','pp', 'n')
pk2021 = get_and_format_nst_team_stats('20202021','pk', 'n')

# %%
pp2021.shape
# Out:
# (1506, 62)

# %%
features2021 = merge_team_stats(primary2021,pp2021,pk2021)

# %%
features2021 = calculate_team_features(features2021)

# %%
features2021.head()
# Out:
#                                       Game Team                 Unnamed: 2  \
# 0        2021-01-13 - Penguins 3, Flyers 6  PHI  Limited ReportFull Report
# 1        2021-01-13 - Penguins 3, Flyers 6  PIT  Limited ReportFull Report
# 2   2021-01-13 - Blackhawks 1, Lightning 5  CHI  Limited ReportFull Report
# 3   2021-01-13 - Blackhawks 1, Lightning 5  T.B  Limited ReportFull Report
# 4  2021-01-13 - Canadiens 4, Maple Leafs 5  MTL  Limited ReportFull Report
#
#          TOI  CF  CA    CF%  FF  FA    FF%  SF  SA    SF%  GF  GA     GF%  \
# 0  51.933333  38  48  44.19  30  37  44.78  22  30  42.31   4   2   66.67
# 1  51.933333  48  38  55.81  37  30  55.22  30  22  57.69   2   4   33.33
# 2  45.583333  33  34  49.25  23  27  46.00  19  22  46.34   0   3    0.00
# 3  45.583333  34  33  50.75  27  23  54.00  22  19  53.66   3   0  100.00
# 4  48.600000  47  52  47.47  33  33  50.00  22  20  52.38   2   2   50.00
#
#     xGF   xGA   xGF%  SCF  SCA   SCF%  HDCF  HDCA  HDCF%  HDSF  HDSA  HDSF%  \
# 0  1.94  1.58  55.04   18   19  48.65    10     7  58.82     8     6  57.14
# 1  1.58  1.94  44.96   19   18  51.35     7    10  41.18     6     8  42.86
# 2  1.07  1.79  37.29   19   24  44.19     2     7  22.22     2     7  22.22
# 3  1.79  1.07  62.71   24   19  55.81     7     2  77.78     7     2  77.78
# 4  1.78  1.77  50.06   25   30  45.45     9     6  60.00     5     4  55.56
#
#    HDGF  HDGA  HDGF%  HDSH%   HDSV%  MDCF  MDCA  MDCF%  MDSF  MDSA  MDSF%  \
# 0     4     1   80.0  50.00   83.33     8    12   40.0     2     7  22.22
# 1     1     4   20.0  16.67   50.00    12     8   60.0     7     2  77.78
# 2     0     2    0.0   0.00   71.43    17    17   50.0    12     9  57.14
# 3     2     0  100.0  28.57  100.00    17    17   50.0     9    12  42.86
# 4     1     1   50.0  20.00   75.00    16    24   40.0     7     9  43.75
#
#    MDGF  MDGA  MDGF%  MDSH%   MDSV%  LDCF  LDCA  LDCF%  LDSF  LDSA  LDSF%  \
# 0     0     1    0.0   0.00   85.71    16    23  41.03    10    15  40.00
# 1     1     0  100.0  14.29  100.00    23    16  58.97    15    10  60.00
# 2     0     1    0.0   0.00   88.89     8     9  47.06     5     6  45.45
# 3     1     0  100.0  11.11  100.00     9     8  52.94     6     5  54.55
# 4     1     0  100.0  14.29  100.00    18    20  47.37     8     7  53.33
#
#    LDGF  LDGA  LDGF%  LDSH%   LDSV%    SH%     SV%    PDO  Attendance  \
# 0     0     0    NaN    0.0  100.00  18.18   93.33  1.115           0
# 1     0     0    NaN    0.0  100.00   6.67   81.82  0.885           0
# 2     0     0    NaN    0.0  100.00   0.00   86.36  0.864           0
# 3     0     0    NaN    0.0  100.00  13.64  100.00  1.136           0
# 4     0     1    0.0    0.0   85.71   9.09   90.00  0.991           0
#
#         Date  Game_Number        Team_Key    TOI_pk  xGA_pk    TOI_pp  xGF_pp  \
# 0 2021-01-13            1  PHI_2021-01-13  5.783333    0.28  2.133333    0.28
# 1 2021-01-13            1  PIT_2021-01-13  2.133333    0.28  5.783333    0.28
# 2 2021-01-13            1  CHI_2021-01-13  7.350000    0.93  6.300000    0.49
# 3 2021-01-13            1  T.B_2021-01-13  6.300000    0.49  7.350000    0.93
# 4 2021-01-13            1  MTL_2021-01-13  5.983333    1.64  5.416667    0.88
#
#    sum_rolling20_TOI_5v5  sum_rolling20_FF_5v5  sum_rolling20_FA_5v5  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
#
#    sum_rolling20_GF_5v5  sum_rolling20_GA_5v5  sum_rolling20_xGF_5v5  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#    sum_rolling20_xGA_5v5  sum_rolling20_SF_5v5  last_20_FF%_5v5  \
# 0                    NaN                   NaN              NaN
# 1                    NaN                   NaN              NaN
# 2                    NaN                   NaN              NaN
# 3                    NaN                   NaN              NaN
# 4                    NaN                   NaN              NaN
#
#    last_20_GF%_5v5  last_20_xGF%_5v5  last_20_SH%  sum_rolling20_TOI_pp  \
# 0              NaN               NaN          NaN                   NaN
# 1              NaN               NaN          NaN                   NaN
# 2              NaN               NaN          NaN                   NaN
# 3              NaN               NaN          NaN                   NaN
# 4              NaN               NaN          NaN                   NaN
#
#    sum_rolling20_xGF_pp  last20_pp_TOI_per_game  last20_xGF_per_min_pp  \
# 0                   NaN                     NaN                    NaN
# 1                   NaN                     NaN                    NaN
# 2                   NaN                     NaN                    NaN
# 3                   NaN                     NaN                    NaN
# 4                   NaN                     NaN                    NaN
#
#    sum_rolling20_TOI_pk  sum_rolling20_xGA_pk  last20_pk_TOI_per_game  \
# 0                   NaN                   NaN                     NaN
# 1                   NaN                   NaN                     NaN
# 2                   NaN                   NaN                     NaN
# 3                   NaN                   NaN                     NaN
# 4                   NaN                   NaN                     NaN
#
#    last20_xGA_per_min_pk Last_Game_Date Days_Since_Last_Game  B2B
# 0                    NaN            NaT                  NaT    0
# 1                    NaN            NaT                  NaT    0
# 2                    NaN            NaT                  NaT    0
# 3                    NaN            NaT                  NaT    0
# 4                    NaN            NaT                  NaT    0

# %%
results2021 = get_game_results('2021-01-13', '2021-04-29')
# Out:
# Scraping the schedule between 2021-01-13 and 2021-04-29

# %%
results2021.shape
# Out:
# (767, 12)

# %%
df_20202021 = merge_starters_and_features(results2021, goalie_features_dfB, features2021, feature_columns, goalie_feature_columns)

# %%
df_20202021.isna().sum()
# Out:
# game_id                          0
# date                             0
# venue                            0
# home_team                        0
# away_team                        0
# start_time                       0
# home_score                       0
# away_score                       0
# status                           0
# Home_Team_Won                    0
# Home_Team_Key                    0
# Away_Team_Key                    0
# home_goalie                     10
# home_Last_20_FenwickSV%        110
# home_Last_20_GSAx/60           110
# home_Last_20_HDCSV%            110
# away_goalie                     12
# away_Last_20_FenwickSV%        115
# away_Last_20_GSAx/60           115
# away_Last_20_HDCSV%            115
# home_Team_Key                    1
# home_last_20_FF%_5v5           324
# home_last_20_GF%_5v5           324
# home_last_20_xGF%_5v5          324
# home_last_20_SH%               324
# home_last20_pp_TOI_per_game    324
# home_last20_xGF_per_min_pp     324
# home_last20_pk_TOI_per_game    324
# home_last20_xGA_per_min_pk     324
# home_B2B                         1
# away_Team_Key                    1
# away_last_20_FF%_5v5           324
# away_last_20_GF%_5v5           324
# away_last_20_xGF%_5v5          324
# away_last_20_SH%               324
# away_last20_pp_TOI_per_game    324
# away_last20_xGF_per_min_pp     324
# away_last20_pk_TOI_per_game    324
# away_last20_xGA_per_min_pk     324
# away_B2B                         1
# dtype: int64

# %%
#folling up with NST about this missing game
df_20202021[df_20202021['home_Team_Key'].isna()]
# Out:
#         game_id        date                              venue home_team  \
# 659  2020020651  2021-04-11  Nassau Veterans Memorial Coliseum       NYI
#
#     away_team          start_time  home_score  away_score status  \
# 659       NYR 2021-04-11 23:00:00           3           2  Final
#
#      Home_Team_Won   Home_Team_Key   Away_Team_Key   home_goalie  \
# 659              1  NYI_2021-04-11  NYR_2021-04-11  Ilya Sorokin
#
#      home_Last_20_FenwickSV%  home_Last_20_GSAx/60  home_Last_20_HDCSV%  \
# 659                      NaN                   NaN                  NaN
#
#          away_goalie  away_Last_20_FenwickSV%  away_Last_20_GSAx/60  \
# 659  Igor Shesterkin                  0.94335              0.061426
#
#      away_Last_20_HDCSV% home_Team_Key  home_last_20_FF%_5v5  \
# 659             0.896714           NaN                   NaN
#
#      home_last_20_GF%_5v5  home_last_20_xGF%_5v5  home_last_20_SH%  \
# 659                   NaN                    NaN               NaN
#
#      home_last20_pp_TOI_per_game  home_last20_xGF_per_min_pp  \
# 659                          NaN                         NaN
#
#      home_last20_pk_TOI_per_game  home_last20_xGA_per_min_pk  home_B2B  \
# 659                          NaN                         NaN       NaN
#
#     away_Team_Key  away_last_20_FF%_5v5  away_last_20_GF%_5v5  \
# 659           NaN                   NaN                   NaN
#
#      away_last_20_xGF%_5v5  away_last_20_SH%  away_last20_pp_TOI_per_game  \
# 659                    NaN               NaN                          NaN
#
#      away_last20_xGF_per_min_pp  away_last20_pk_TOI_per_game  \
# 659                         NaN                          NaN
#
#      away_last20_xGA_per_min_pk  away_B2B
# 659                         NaN       NaN

# %% [markdown]
# #### Combine and Save

# %%
all_games_rolling20_noSVA = pd.concat([df_20172018, df_20182019, df_20192020, df_20202021])

# %%
#impute goalie stats where lack of games causing NaN
all_games_rolling20_noSVA['away_Last_20_FenwickSV%'] = np.where(all_games_rolling20_noSVA['away_Last_20_FenwickSV%'].isna(), ig_FenwickSV,all_games_rolling20_noSVA['away_Last_20_FenwickSV%'])
all_games_rolling20_noSVA['away_Last_20_GSAx/60'] = np.where(all_games_rolling20_noSVA['away_Last_20_GSAx/60'].isna(), ig_GSAx60, all_games_rolling20_noSVA['away_Last_20_GSAx/60'])
all_games_rolling20_noSVA['away_Last_20_HDCSV%'] = np.where(all_games_rolling20_noSVA['away_Last_20_HDCSV%'].isna(), ig_HDCSV, all_games_rolling20_noSVA['away_Last_20_HDCSV%'])
all_games_rolling20_noSVA['home_Last_20_FenwickSV%'] = np.where(all_games_rolling20_noSVA['home_Last_20_FenwickSV%'].isna(), ig_FenwickSV,all_games_rolling20_noSVA['home_Last_20_FenwickSV%'])
all_games_rolling20_noSVA['home_Last_20_GSAx/60'] = np.where(all_games_rolling20_noSVA['home_Last_20_GSAx/60'].isna(), ig_GSAx60, all_games_rolling20_noSVA['home_Last_20_GSAx/60'])
all_games_rolling20_noSVA['home_Last_20_HDCSV%'] = np.where(all_games_rolling20_noSVA['home_Last_20_HDCSV%'].isna(), ig_HDCSV, all_games_rolling20_noSVA['home_Last_20_HDCSV%'])

# %%
all_games_rolling20_noSVA.isna().sum()
# Out:
# game_id                           0
# date                              0
# venue                             0
# home_team                         0
# away_team                         0
# start_time                        0
# home_score                        0
# away_score                        0
# status                            0
# Home_Team_Won                     0
# Home_Team_Key                     0
# Away_Team_Key                     0
# home_goalie                      12
# home_Last_20_FenwickSV%           0
# home_Last_20_GSAx/60              0
# home_Last_20_HDCSV%               0
# away_goalie                      16
# away_Last_20_FenwickSV%           0
# away_Last_20_GSAx/60              0
# away_Last_20_HDCSV%               0
# home_Team_Key                     3
# home_last_20_FF%_5v5           1301
# home_last_20_GF%_5v5           1301
# home_last_20_xGF%_5v5          1301
# home_last_20_SH%               1301
# home_last20_pp_TOI_per_game    1301
# home_last20_xGF_per_min_pp     1301
# home_last20_pk_TOI_per_game    1301
# home_last20_xGA_per_min_pk     1301
# home_B2B                          3
# away_Team_Key                     3
# away_last_20_FF%_5v5           1307
# away_last_20_GF%_5v5           1307
# away_last_20_xGF%_5v5          1307
# away_last_20_SH%               1307
# away_last20_pp_TOI_per_game    1307
# away_last20_xGF_per_min_pp     1307
# away_last20_pk_TOI_per_game    1307
# away_last20_xGA_per_min_pk     1307
# away_B2B                          3
# dtype: int64

# %%
all_games_rolling20_noSVA.to_csv('data/all_games_rolling20_noSVA.csv')

# %% [markdown]
# ### Calculating Weighted Rolling Features
# This is a work in progress

# %%
def calculate_weighted_team_features(df, rolling_games = 20):
    weights = np.arange(1,rolling_games)
    df[f'sum_rolling{rolling_games}_TOI_5v5'] = df.groupby('Team')['TOI'].transform(lambda x: x.rolling(rolling_games, rolling_games).sum().shift())
    df[f'sum_rolling{rolling_games}_FF_5v5'] = df.groupby('Team')['FF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_FA_5v5'] = df.groupby('Team')['FA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GF_5v5'] = df.groupby('Team')['GF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GA_5v5'] = df.groupby('Team')['GA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGF_5v5'] = df.groupby('Team')['xGF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGA_5v5'] = df.groupby('Team')['xGA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_SF_5v5'] = df.groupby('Team')['SF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last_{rolling_games}_FF%_5v5'] = df[f'sum_rolling{rolling_games}_FF_5v5']*100/ (df[f'sum_rolling{rolling_games}_FF_5v5']+df[f'sum_rolling{rolling_games}_FA_5v5'])
    df[f'last_{rolling_games}_GF%_5v5'] = df[f'sum_rolling{rolling_games}_GF_5v5']*100/ (df[f'sum_rolling{rolling_games}_GF_5v5']+df['sum_rolling20_GA_5v5'])
    df[f'last_{rolling_games}_xGF%_5v5'] = df['sum_rolling20_xGF_5v5']*100/ (df['sum_rolling20_xGF_5v5']+df[f'sum_rolling{rolling_games}_GA_5v5'])
    df[f'last_{rolling_games}_SH%'] = df[f'sum_rolling{rolling_games}_GF_5v5']*100 / df[f'sum_rolling{rolling_games}_SF_5v5']
    
    
    #fix NaNs in pp and pk features
    df['TOI_pp'] = np.where(df['TOI_pp'].isna(), 0, df['TOI_pp'])
    df['TOI_pk'] = np.where(df['TOI_pk'].isna(), 0, df['TOI_pk'])
    df['xGF_pp'] = np.where(df['xGF_pp'].isna(), 0, df['xGF_pp'])
    df['xGA_pk'] = np.where(df['xGA_pk'].isna(), 0, df['xGA_pk'])
    
    #pp features
    df[f'sum_rolling{rolling_games}_TOI_pp'] = df.groupby('Team')['TOI_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGF_pp'] = df.groupby('Team')['xGF_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last{rolling_games}_pp_TOI_per_game'] = df.groupby('Team')['TOI_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).mean().shift())
    df[f'last{rolling_games}_xGF_per_min_pp'] = df[f'sum_rolling{rolling_games}_xGF_pp'] / df[f'sum_rolling{rolling_games}_TOI_pp'] 
    
    #pk features
    df[f'sum_rolling{rolling_games}_TOI_pk'] = df.groupby('Team')['TOI_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGA_pk'] = df.groupby('Team')['xGA_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last{rolling_games}_pk_TOI_per_game'] = df.groupby('Team')['TOI_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).mean().shift())
    df[f'last{rolling_games}_xGA_per_min_pk'] = df[f'sum_rolling{rolling_games}_xGA_pk'] / df[f'sum_rolling{rolling_games}_TOI_pk'] 
    
    #to get back to back category
    df['Last_Game_Date'] = df.groupby('Team')['Date'].shift()
    df['Days_Since_Last_Game'] = df['Date'] - df['Last_Game_Date']
    df['B2B'] = np.where(df['Days_Since_Last_Game'] == '1 days', 1, 0)
    
    return df

# %%
df = primary
w = np.arange(1, 21)
rolling_games = 20
df[f'sum_rolling{rolling_games}_FF_5v5'] = df.groupby('Team')['FF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).apply(lambda x: (x * w).sum()).shift())
df[f'sum_rolling{rolling_games}_FA_5v5'] = df.groupby('Team')['FA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).apply(lambda x: (x * w).sum()).shift())
df[f'last_{rolling_games}_FF%_5v5'] = df[f'sum_rolling{rolling_games}_FF_5v5']*100/ (df[f'sum_rolling{rolling_games}_FF_5v5']+df[f'sum_rolling{rolling_games}_FA_5v5'])

# %%
df.head()
# Out:
#                                  Game Team                 Unnamed: 2  \
# 0  2017-10-04 - Maple Leafs 7, Jets 2  TOR  Limited ReportFull Report
# 1  2017-10-04 - Maple Leafs 7, Jets 2  WPG  Limited ReportFull Report
# 2    2017-10-04 - Blues 5, Penguins 4  PIT  Limited ReportFull Report
# 3    2017-10-04 - Blues 5, Penguins 4  STL  Limited ReportFull Report
# 4     2017-10-04 - Flames 0, Oilers 3  CGY  Limited ReportFull Report
#
#          TOI  CF  CA    CF%  FF  FA    FF%  SF  SA    SF%  GF  GA    GF%  \
# 0  39.133333  37  38  49.33  24  24  50.00  17  18  48.57   5   2  71.43
# 1  39.133333  38  37  50.67  24  24  50.00  18  17  51.43   2   5  28.57
# 2  46.366667  58  48  54.72  43  38  53.09  28  27  50.91   3   2  60.00
# 3  46.366667  48  58  45.28  38  43  46.91  27  28  49.09   2   3  40.00
# 4  52.950000  53  71  42.74  37  57  39.36  24  41  36.92   0   2   0.00
#
#     xGF   xGA   xGF%  SCF  SCA   SCF%  HDCF  HDCA  HDCF%  HDSF  HDSA  HDSF%  \
# 0  1.38  1.56  46.86   20   16  55.56     7     8  46.67     6     8  42.86
# 1  1.56  1.38  53.14   16   20  44.44     8     7  53.33     8     6  57.14
# 2  2.63  2.28  53.56   26   25  50.98    10    11  47.62     4     9  30.77
# 3  2.28  2.63  46.44   25   26  49.02    11    10  52.38     9     4  69.23
# 4  1.81  3.49  34.12   20   29  40.82     9    18  33.33     7    14  33.33
#
#    HDGF  HDGA  HDGF%  HDSH%   HDSV%  MDCF  MDCA  MDCF%  MDSF  MDSA  MDSF%  \
# 0     2     2   50.0  33.33   75.00    13     8  61.90     6     3  66.67
# 1     2     2   50.0  25.00   66.67     8    13  38.10     3     6  33.33
# 2     0     1    0.0   0.00   88.89    16    14  53.33     7     8  46.67
# 3     1     0  100.0  11.11  100.00    14    16  46.67     8     7  53.33
# 4     0     2    0.0   0.00   85.71    11    11  50.00     4     5  44.44
#
#    MDGF  MDGA  MDGF%  MDSH%   MDSV%  LDCF  LDCA  LDCF%  LDSF  LDSA  LDSF%  \
# 0     2     0  100.0  33.33  100.00    13    16  44.83     4     6  40.00
# 1     0     2    0.0   0.00   66.67    16    13  55.17     6     4  60.00
# 2     0     1    0.0   0.00   87.50    28    21  57.14    14    10  58.33
# 3     1     0  100.0  12.50  100.00    21    28  42.86    10    14  41.67
# 4     0     0    NaN   0.00  100.00    21    36  36.84     9    22  29.03
#
#    LDGF  LDGA  LDGF%  LDSH%   LDSV%    SH%    SV%    PDO  Attendance  \
# 0     1     0  100.0  25.00  100.00  29.41  88.89  1.183       15321
# 1     0     1    0.0   0.00   75.00  11.11  70.59  0.817       15321
# 2     3     0  100.0  21.43  100.00  10.71  92.59  1.033       18652
# 3     0     3    0.0   0.00   78.57   7.41  89.29  0.967       18652
# 4     0     0    NaN   0.00  100.00   0.00  95.12  0.951       18347
#
#         Date  Game_Number        Team_Key  sum_rolling5_FF_5v5  \
# 0 2017-10-04            1  TOR_2017-10-04                  NaN
# 1 2017-10-04            1  WPG_2017-10-04                  NaN
# 2 2017-10-04            1  PIT_2017-10-04                  NaN
# 3 2017-10-04            1  STL_2017-10-04                  NaN
# 4 2017-10-04            1  CGY_2017-10-04                  NaN
#
#    sum_rolling5_FA_5v5  last_5_FF%_5v5  sum_rolling20_FF_5v5  \
# 0                  NaN             NaN                   NaN
# 1                  NaN             NaN                   NaN
# 2                  NaN             NaN                   NaN
# 3                  NaN             NaN                   NaN
# 4                  NaN             NaN                   NaN
#
#    sum_rolling20_FA_5v5  last_20_FF%_5v5
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN

# %%
df[df['Team'] == 'NYI'][['FF', 'sum_rolling20_FF_5v5', 'last_20_FF%_5v5']].head(22)
# Out:
#      FF  sum_rolling20_FF_5v5  last_20_FF%_5v5
# 25   40                   NaN              NaN
# 39   32                   NaN              NaN
# 64   33                   NaN              NaN
# 97   38                   NaN              NaN
# 150  24                   NaN              NaN
# 157  34                   NaN              NaN
# 190  37                   NaN              NaN
# 228  30                   NaN              NaN
# 251  28                   NaN              NaN
# 291  34                   NaN              NaN
# 325  27                   NaN              NaN
# 338  30                   NaN              NaN
# 372  45                   NaN              NaN
# 427  37                   NaN              NaN
# 449  43                   NaN              NaN
# 491  24                   NaN              NaN
# 512  31                   NaN              NaN
# 557  39                   NaN              NaN
# 596  34                   NaN              NaN
# 609  25                   NaN              NaN
# 644  42                6934.0        49.320720
# 668  36                7109.0        49.567703

# %%
40+32+33+38+24
# Out:
# 167

# %%
(40*1+32*2+33*3+38*4+24*5) /
# Out:
# 95.0

# %%
def calculate_team_features(df, rolling_games = 20):

    df[f'sum_rolling{rolling_games}_TOI_5v5'] = df.groupby('Team')['TOI'].transform(lambda x: x.rolling(rolling_games, rolling_games).sum().shift())
    df[f'sum_rolling{rolling_games}_FF_5v5'] = df.groupby('Team')['FF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_FA_5v5'] = df.groupby('Team')['FA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GF_5v5'] = df.groupby('Team')['GF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_GA_5v5'] = df.groupby('Team')['GA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGF_5v5'] = df.groupby('Team')['xGF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGA_5v5'] = df.groupby('Team')['xGA'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_SF_5v5'] = df.groupby('Team')['SF'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last_{rolling_games}_FF%_5v5'] = df[f'sum_rolling{rolling_games}_FF_5v5']*100/ (df[f'sum_rolling{rolling_games}_FF_5v5']+df[f'sum_rolling{rolling_games}_FA_5v5'])
    df[f'last_{rolling_games}_GF%_5v5'] = df[f'sum_rolling{rolling_games}_GF_5v5']*100/ (df[f'sum_rolling{rolling_games}_GF_5v5']+df[f'sum_rolling{rolling_games}_GA_5v5'])
    df[f'last_{rolling_games}_xGF%_5v5'] = df[f'sum_rolling{rolling_games}_xGF_5v5']*100/ (df[f'sum_rolling{rolling_games}_xGF_5v5']+df[f'sum_rolling{rolling_games}_xGA_5v5'])
    df[f'last_{rolling_games}_SH%'] = df[f'sum_rolling{rolling_games}_GF_5v5']*100 / df[f'sum_rolling{rolling_games}_SF_5v5']
    
    
    #fix NaNs in pp and pk features
    df['TOI_pp'] = np.where(df['TOI_pp'].isna(), 0, df['TOI_pp'])
    df['TOI_pk'] = np.where(df['TOI_pk'].isna(), 0, df['TOI_pk'])
    df['xGF_pp'] = np.where(df['xGF_pp'].isna(), 0, df['xGF_pp'])
    df['xGA_pk'] = np.where(df['xGA_pk'].isna(), 0, df['xGA_pk'])
    
    #pp features
    df[f'sum_rolling{rolling_games}_TOI_pp'] = df.groupby('Team')['TOI_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGF_pp'] = df.groupby('Team')['xGF_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last{rolling_games}_pp_TOI_per_game'] = df.groupby('Team')['TOI_pp'].transform(lambda x: x.rolling(rolling_games, rolling_games ).mean().shift())
    df[f'last{rolling_games}_xGF_per_min_pp'] = df[f'sum_rolling{rolling_games}_xGF_pp'] / df[f'sum_rolling{rolling_games}_TOI_pp'] 
    
    #pk features
    df[f'sum_rolling{rolling_games}_TOI_pk'] = df.groupby('Team')['TOI_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'sum_rolling{rolling_games}_xGA_pk'] = df.groupby('Team')['xGA_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).sum().shift())
    df[f'last{rolling_games}_pk_TOI_per_game'] = df.groupby('Team')['TOI_pk'].transform(lambda x: x.rolling(rolling_games, rolling_games ).mean().shift())
    df[f'last{rolling_games}_xGA_per_min_pk'] = df[f'sum_rolling{rolling_games}_xGA_pk'] / df[f'sum_rolling{rolling_games}_TOI_pk'] 
    
    #to get back to back category
    df['Last_Game_Date'] = df.groupby('Team')['Date'].shift()
    df['Days_Since_Last_Game'] = df['Date'] - df['Last_Game_Date']
    df['B2B'] = np.where(df['Days_Since_Last_Game'] == '1 days', 1, 0)
    
    return df

# %%
primary
# Out:
#                                     Game Team                 Unnamed: 2  \
# 0     2017-10-04 - Maple Leafs 7, Jets 2  TOR  Limited ReportFull Report
# 1     2017-10-04 - Maple Leafs 7, Jets 2  WPG  Limited ReportFull Report
# 2       2017-10-04 - Blues 5, Penguins 4  PIT  Limited ReportFull Report
# 3       2017-10-04 - Blues 5, Penguins 4  STL  Limited ReportFull Report
# 4        2017-10-04 - Flames 0, Oilers 3  CGY  Limited ReportFull Report
# ...                                  ...  ...                        ...
# 2537    2018-04-07 - Canucks 2, Oilers 3  VAN  Limited ReportFull Report
# 2538       2018-04-07 - Stars 4, Kings 2  DAL  Limited ReportFull Report
# 2539       2018-04-07 - Stars 4, Kings 2  L.A  Limited ReportFull Report
# 2540       2018-04-07 - Wild 6, Sharks 3  MIN  Limited ReportFull Report
# 2541       2018-04-07 - Wild 6, Sharks 3  S.J  Limited ReportFull Report
#
#             TOI  CF  CA    CF%  FF  FA    FF%  SF  SA    SF%  GF  GA     GF%  \
# 0     39.133333  37  38  49.33  24  24  50.00  17  18  48.57   5   2   71.43
# 1     39.133333  38  37  50.67  24  24  50.00  18  17  51.43   2   5   28.57
# 2     46.366667  58  48  54.72  43  38  53.09  28  27  50.91   3   2   60.00
# 3     46.366667  48  58  45.28  38  43  46.91  27  28  49.09   2   3   40.00
# 4     52.950000  53  71  42.74  37  57  39.36  24  41  36.92   0   2    0.00
# ...         ...  ..  ..    ...  ..  ..    ...  ..  ..    ...  ..  ..     ...
# 2537  51.583333  52  54  49.06  44  40  52.38  32  28  53.33   2   0  100.00
# 2538  50.700000  28  56  33.33  24  44  35.29  16  35  31.37   4   2   66.67
# 2539  50.700000  56  28  66.67  44  24  64.71  35  16  68.63   2   4   33.33
# 2540  53.466667  52  56  48.15  31  37  45.59  23  22  51.11   5   2   71.43
# 2541  53.466667  56  52  51.85  37  31  54.41  22  23  48.89   2   5   28.57
#
#        xGF   xGA   xGF%  SCF  SCA   SCF%  HDCF  HDCA  HDCF%  HDSF  HDSA  \
# 0     1.38  1.56  46.86   20   16  55.56     7     8  46.67     6     8
# 1     1.56  1.38  53.14   16   20  44.44     8     7  53.33     8     6
# 2     2.63  2.28  53.56   26   25  50.98    10    11  47.62     4     9
# 3     2.28  2.63  46.44   25   26  49.02    11    10  52.38     9     4
# 4     1.81  3.49  34.12   20   29  40.82     9    18  33.33     7    14
# ...    ...   ...    ...  ...  ...    ...   ...   ...    ...   ...   ...
# 2537  2.73  2.99  47.71   28   32  46.67    15    16  48.39    12     9
# 2538  2.15  1.75  55.18   22   21  51.16     9     5  64.29     9     5
# 2539  1.75  2.15  44.82   21   22  48.84     5     9  35.71     5     9
# 2540  1.84  1.53  54.62   25   21  54.35    14    10  58.33    12     6
# 2541  1.53  1.84  45.38   21   25  45.65    10    14  41.67     6    12
#
#       HDSF%  HDGF  HDGA  HDGF%  HDSH%   HDSV%  MDCF  MDCA  MDCF%  MDSF  MDSA  \
# 0     42.86     2     2   50.0  33.33   75.00    13     8  61.90     6     3
# 1     57.14     2     2   50.0  25.00   66.67     8    13  38.10     3     6
# 2     30.77     0     1    0.0   0.00   88.89    16    14  53.33     7     8
# 3     69.23     1     0  100.0  11.11  100.00    14    16  46.67     8     7
# 4     33.33     0     2    0.0   0.00   85.71    11    11  50.00     4     5
# ...     ...   ...   ...    ...    ...     ...   ...   ...    ...   ...   ...
# 2537  57.14     2     0  100.0  16.67  100.00    13    16  44.83     6    12
# 2538  64.29     3     1   75.0  33.33   80.00    13    16  44.83     4     7
# 2539  35.71     1     3   25.0  20.00   66.67    16    13  55.17     7     4
# 2540  66.67     3     2   60.0  25.00   66.67    11    11  50.00     4     4
# 2541  33.33     2     3   40.0  33.33   75.00    11    11  50.00     4     4
#
#       MDSF%  MDGF  MDGA  MDGF%  MDSH%   MDSV%  LDCF  LDCA  LDCF%  LDSF  LDSA  \
# 0     66.67     2     0  100.0  33.33  100.00    13    16  44.83     4     6
# 1     33.33     0     2    0.0   0.00   66.67    16    13  55.17     6     4
# 2     46.67     0     1    0.0   0.00   87.50    28    21  57.14    14    10
# 3     53.33     1     0  100.0  12.50  100.00    21    28  42.86    10    14
# 4     44.44     0     0    NaN   0.00  100.00    21    36  36.84     9    22
# ...     ...   ...   ...    ...    ...     ...   ...   ...    ...   ...   ...
# 2537  33.33     0     0    NaN   0.00  100.00    22    16  57.89    12     5
# 2538  36.36     1     0  100.0  25.00  100.00     5    32  13.51     2    21
# 2539  63.64     0     1    0.0   0.00   75.00    32     5  86.49    21     2
# 2540  50.00     1     0  100.0  25.00  100.00    22    27  44.90     7    12
# 2541  50.00     0     1    0.0   0.00   75.00    27    22  55.10    12     7
#
#       LDSF%  LDGF  LDGA  LDGF%  LDSH%   LDSV%    SH%     SV%    PDO  \
# 0     40.00     1     0  100.0  25.00  100.00  29.41   88.89  1.183
# 1     60.00     0     1    0.0   0.00   75.00  11.11   70.59  0.817
# 2     58.33     3     0  100.0  21.43  100.00  10.71   92.59  1.033
# 3     41.67     0     3    0.0   0.00   78.57   7.41   89.29  0.967
# 4     29.03     0     0    NaN   0.00  100.00   0.00   95.12  0.951
# ...     ...   ...   ...    ...    ...     ...    ...     ...    ...
# 2537  70.59     0     0    NaN   0.00  100.00   6.25  100.00  1.063
# 2538   8.70     0     1    0.0   0.00   95.24  25.00   94.29  1.193
# 2539  91.30     1     0  100.0   4.76  100.00   5.71   75.00  0.807
# 2540  36.84     1     0  100.0  14.29  100.00  21.74   90.91  1.126
# 2541  63.16     0     1    0.0   0.00   85.71   9.09   78.26  0.874
#
#       Attendance       Date  Game_Number        Team_Key  sum_rolling5_FF_5v5  \
# 0          15321 2017-10-04            1  TOR_2017-10-04                  NaN
# 1          15321 2017-10-04            1  WPG_2017-10-04                  NaN
# 2          18652 2017-10-04            1  PIT_2017-10-04                  NaN
# 3          18652 2017-10-04            1  STL_2017-10-04                  NaN
# 4          18347 2017-10-04            1  CGY_2017-10-04                  NaN
# ...          ...        ...          ...             ...                  ...
# 2537       18347 2018-04-07           82  VAN_2018-04-07                511.0
# 2538       18230 2018-04-07           82  DAL_2018-04-07                460.0
# 2539       18230 2018-04-07           82  L.A_2018-04-07                477.0
# 2540       17562 2018-04-07           82  MIN_2018-04-07                511.0
# 2541       17562 2018-04-07           82  S.J_2018-04-07                561.0
#
#       sum_rolling5_FA_5v5  last_5_FF%_5v5  sum_rolling20_FF_5v5  \
# 0                     NaN             NaN                   NaN
# 1                     NaN             NaN                   NaN
# 2                     NaN             NaN                   NaN
# 3                     NaN             NaN                   NaN
# 4                     NaN             NaN                   NaN
# ...                   ...             ...                   ...
# 2537                487.0       51.202405                7070.0
# 2538                528.0       46.558704                6517.0
# 2539                491.0       49.276860                6958.0
# 2540                483.0       51.408451                6886.0
# 2541                518.0       51.992586                7803.0
#
#       sum_rolling20_FA_5v5  last_20_FF%_5v5  sum_rolling10_TOI_5v5  \
# 0                      NaN              NaN                    NaN
# 1                      NaN              NaN                    NaN
# 2                      NaN              NaN                    NaN
# 3                      NaN              NaN                    NaN
# 4                      NaN              NaN                    NaN
# ...                    ...              ...                    ...
# 2537                7414.0        48.812483             506.100000
# 2538                6874.0        48.667015             482.550000
# 2539                7150.0        49.319535             496.366667
# 2540                6920.0        49.876865             486.883333
# 2541                7415.0        51.274806             497.566667
#
#       sum_rolling10_FF_5v5  sum_rolling10_FA_5v5  sum_rolling10_GF_5v5  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 2537                 333.0                 353.0                  23.0
# 2538                 305.0                 325.0                  16.0
# 2539                 326.0                 339.0                  18.0
# 2540                 311.0                 332.0                  14.0
# 2541                 366.0                 354.0                  23.0
#
#       sum_rolling10_GA_5v5  sum_rolling10_xGF_5v5  sum_rolling10_xGA_5v5  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 2537                  20.0                  16.43                  19.30
# 2538                  16.0                  16.69                  16.23
# 2539                  15.0                  14.83                  17.01
# 2540                  14.0                  15.10                  15.72
# 2541                  18.0                  19.91                  16.93
#
#       sum_rolling10_SF_5v5  last_10_FF%_5v5  last_10_GF%_5v5  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 2537                 237.0        48.542274        53.488372
# 2538                 208.0        48.412698        50.000000
# 2539                 223.0        49.022556        54.545455
# 2540                 230.0        48.367030        50.000000
# 2541                 259.0        50.833333        56.097561
#
#       last_10_xGF%_5v5  last_10_SH%
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN
# ...                ...          ...
# 2537         45.983767     9.704641
# 2538         50.698663     7.692308
# 2539         46.576633     8.071749
# 2540         48.994160     6.086957
# 2541         54.044517     8.880309
#
# [2542 rows x 80 columns]

# %%
test = merge_team_stats(primary, pp, pk)

# %%
test.head()
# Out:
#                                  Game Team                 Unnamed: 2  \
# 0  2017-10-04 - Maple Leafs 7, Jets 2  TOR  Limited ReportFull Report
# 1  2017-10-04 - Maple Leafs 7, Jets 2  WPG  Limited ReportFull Report
# 2    2017-10-04 - Blues 5, Penguins 4  PIT  Limited ReportFull Report
# 3    2017-10-04 - Blues 5, Penguins 4  STL  Limited ReportFull Report
# 4     2017-10-04 - Flames 0, Oilers 3  CGY  Limited ReportFull Report
#
#          TOI  CF  CA    CF%  FF  FA    FF%  SF  SA    SF%  GF  GA    GF%  \
# 0  39.133333  37  38  49.33  24  24  50.00  17  18  48.57   5   2  71.43
# 1  39.133333  38  37  50.67  24  24  50.00  18  17  51.43   2   5  28.57
# 2  46.366667  58  48  54.72  43  38  53.09  28  27  50.91   3   2  60.00
# 3  46.366667  48  58  45.28  38  43  46.91  27  28  49.09   2   3  40.00
# 4  52.950000  53  71  42.74  37  57  39.36  24  41  36.92   0   2   0.00
#
#     xGF   xGA   xGF%  SCF  SCA   SCF%  HDCF  HDCA  HDCF%  HDSF  HDSA  HDSF%  \
# 0  1.38  1.56  46.86   20   16  55.56     7     8  46.67     6     8  42.86
# 1  1.56  1.38  53.14   16   20  44.44     8     7  53.33     8     6  57.14
# 2  2.63  2.28  53.56   26   25  50.98    10    11  47.62     4     9  30.77
# 3  2.28  2.63  46.44   25   26  49.02    11    10  52.38     9     4  69.23
# 4  1.81  3.49  34.12   20   29  40.82     9    18  33.33     7    14  33.33
#
#    HDGF  HDGA  HDGF%  HDSH%   HDSV%  MDCF  MDCA  MDCF%  MDSF  MDSA  MDSF%  \
# 0     2     2   50.0  33.33   75.00    13     8  61.90     6     3  66.67
# 1     2     2   50.0  25.00   66.67     8    13  38.10     3     6  33.33
# 2     0     1    0.0   0.00   88.89    16    14  53.33     7     8  46.67
# 3     1     0  100.0  11.11  100.00    14    16  46.67     8     7  53.33
# 4     0     2    0.0   0.00   85.71    11    11  50.00     4     5  44.44
#
#    MDGF  MDGA  MDGF%  MDSH%   MDSV%  LDCF  LDCA  LDCF%  LDSF  LDSA  LDSF%  \
# 0     2     0  100.0  33.33  100.00    13    16  44.83     4     6  40.00
# 1     0     2    0.0   0.00   66.67    16    13  55.17     6     4  60.00
# 2     0     1    0.0   0.00   87.50    28    21  57.14    14    10  58.33
# 3     1     0  100.0  12.50  100.00    21    28  42.86    10    14  41.67
# 4     0     0    NaN   0.00  100.00    21    36  36.84     9    22  29.03
#
#    LDGF  LDGA  LDGF%  LDSH%   LDSV%    SH%    SV%    PDO  Attendance  \
# 0     1     0  100.0  25.00  100.00  29.41  88.89  1.183       15321
# 1     0     1    0.0   0.00   75.00  11.11  70.59  0.817       15321
# 2     3     0  100.0  21.43  100.00  10.71  92.59  1.033       18652
# 3     0     3    0.0   0.00   78.57   7.41  89.29  0.967       18652
# 4     0     0    NaN   0.00  100.00   0.00  95.12  0.951       18347
#
#         Date  Game_Number        Team_Key  sum_rolling5_FF_5v5  \
# 0 2017-10-04            1  TOR_2017-10-04                  NaN
# 1 2017-10-04            1  WPG_2017-10-04                  NaN
# 2 2017-10-04            1  PIT_2017-10-04                  NaN
# 3 2017-10-04            1  STL_2017-10-04                  NaN
# 4 2017-10-04            1  CGY_2017-10-04                  NaN
#
#    sum_rolling5_FA_5v5  last_5_FF%_5v5  sum_rolling20_FF_5v5  \
# 0                  NaN             NaN                   NaN
# 1                  NaN             NaN                   NaN
# 2                  NaN             NaN                   NaN
# 3                  NaN             NaN                   NaN
# 4                  NaN             NaN                   NaN
#
#    sum_rolling20_FA_5v5  last_20_FF%_5v5  sum_rolling10_TOI_5v5  \
# 0                   NaN              NaN                    NaN
# 1                   NaN              NaN                    NaN
# 2                   NaN              NaN                    NaN
# 3                   NaN              NaN                    NaN
# 4                   NaN              NaN                    NaN
#
#    sum_rolling10_FF_5v5  sum_rolling10_FA_5v5  sum_rolling10_GF_5v5  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    sum_rolling10_GA_5v5  sum_rolling10_xGF_5v5  sum_rolling10_xGA_5v5  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
#
#    sum_rolling10_SF_5v5  last_10_FF%_5v5  last_10_GF%_5v5  last_10_xGF%_5v5  \
# 0                   NaN              NaN              NaN               NaN
# 1                   NaN              NaN              NaN               NaN
# 2                   NaN              NaN              NaN               NaN
# 3                   NaN              NaN              NaN               NaN
# 4                   NaN              NaN              NaN               NaN
#
#    last_10_SH%     TOI_pk  xGA_pk     TOI_pp  xGF_pp
# 0          NaN  16.000000    1.61   4.866667    1.87
# 1          NaN   4.866667    1.87  16.000000    1.61
# 2          NaN   5.366667    0.54   6.316667    1.02
# 3          NaN   6.316667    1.02   5.366667    0.54
# 4          NaN   4.000000    0.19   2.000000    0.29

# %%
test = calculate_team_features(test, 10)

# %%
test.tail()
# Out:
#                                   Game Team                 Unnamed: 2  \
# 2537  2018-04-07 - Canucks 2, Oilers 3  VAN  Limited ReportFull Report
# 2538     2018-04-07 - Stars 4, Kings 2  DAL  Limited ReportFull Report
# 2539     2018-04-07 - Stars 4, Kings 2  L.A  Limited ReportFull Report
# 2540     2018-04-07 - Wild 6, Sharks 3  MIN  Limited ReportFull Report
# 2541     2018-04-07 - Wild 6, Sharks 3  S.J  Limited ReportFull Report
#
#             TOI  CF  CA    CF%  FF  FA    FF%  SF  SA    SF%  GF  GA     GF%  \
# 2537  51.583333  52  54  49.06  44  40  52.38  32  28  53.33   2   0  100.00
# 2538  50.700000  28  56  33.33  24  44  35.29  16  35  31.37   4   2   66.67
# 2539  50.700000  56  28  66.67  44  24  64.71  35  16  68.63   2   4   33.33
# 2540  53.466667  52  56  48.15  31  37  45.59  23  22  51.11   5   2   71.43
# 2541  53.466667  56  52  51.85  37  31  54.41  22  23  48.89   2   5   28.57
#
#        xGF   xGA   xGF%  SCF  SCA   SCF%  HDCF  HDCA  HDCF%  HDSF  HDSA  \
# 2537  2.73  2.99  47.71   28   32  46.67    15    16  48.39    12     9
# 2538  2.15  1.75  55.18   22   21  51.16     9     5  64.29     9     5
# 2539  1.75  2.15  44.82   21   22  48.84     5     9  35.71     5     9
# 2540  1.84  1.53  54.62   25   21  54.35    14    10  58.33    12     6
# 2541  1.53  1.84  45.38   21   25  45.65    10    14  41.67     6    12
#
#       HDSF%  HDGF  HDGA  HDGF%  HDSH%   HDSV%  MDCF  MDCA  MDCF%  MDSF  MDSA  \
# 2537  57.14     2     0  100.0  16.67  100.00    13    16  44.83     6    12
# 2538  64.29     3     1   75.0  33.33   80.00    13    16  44.83     4     7
# 2539  35.71     1     3   25.0  20.00   66.67    16    13  55.17     7     4
# 2540  66.67     3     2   60.0  25.00   66.67    11    11  50.00     4     4
# 2541  33.33     2     3   40.0  33.33   75.00    11    11  50.00     4     4
#
#       MDSF%  MDGF  MDGA  MDGF%  MDSH%  MDSV%  LDCF  LDCA  LDCF%  LDSF  LDSA  \
# 2537  33.33     0     0    NaN    0.0  100.0    22    16  57.89    12     5
# 2538  36.36     1     0  100.0   25.0  100.0     5    32  13.51     2    21
# 2539  63.64     0     1    0.0    0.0   75.0    32     5  86.49    21     2
# 2540  50.00     1     0  100.0   25.0  100.0    22    27  44.90     7    12
# 2541  50.00     0     1    0.0    0.0   75.0    27    22  55.10    12     7
#
#       LDSF%  LDGF  LDGA  LDGF%  LDSH%   LDSV%    SH%     SV%    PDO  \
# 2537  70.59     0     0    NaN   0.00  100.00   6.25  100.00  1.063
# 2538   8.70     0     1    0.0   0.00   95.24  25.00   94.29  1.193
# 2539  91.30     1     0  100.0   4.76  100.00   5.71   75.00  0.807
# 2540  36.84     1     0  100.0  14.29  100.00  21.74   90.91  1.126
# 2541  63.16     0     1    0.0   0.00   85.71   9.09   78.26  0.874
#
#       Attendance       Date  Game_Number        Team_Key  sum_rolling5_FF_5v5  \
# 2537       18347 2018-04-07           82  VAN_2018-04-07                511.0
# 2538       18230 2018-04-07           82  DAL_2018-04-07                460.0
# 2539       18230 2018-04-07           82  L.A_2018-04-07                477.0
# 2540       17562 2018-04-07           82  MIN_2018-04-07                511.0
# 2541       17562 2018-04-07           82  S.J_2018-04-07                561.0
#
#       sum_rolling5_FA_5v5  last_5_FF%_5v5  sum_rolling20_FF_5v5  \
# 2537                487.0       51.202405                7070.0
# 2538                528.0       46.558704                6517.0
# 2539                491.0       49.276860                6958.0
# 2540                483.0       51.408451                6886.0
# 2541                518.0       51.992586                7803.0
#
#       sum_rolling20_FA_5v5  last_20_FF%_5v5  sum_rolling10_TOI_5v5  \
# 2537                7414.0        48.812483             506.100000
# 2538                6874.0        48.667015             482.550000
# 2539                7150.0        49.319535             496.366667
# 2540                6920.0        49.876865             486.883333
# 2541                7415.0        51.274806             497.566667
#
#       sum_rolling10_FF_5v5  sum_rolling10_FA_5v5  sum_rolling10_GF_5v5  \
# 2537                 333.0                 353.0                  23.0
# 2538                 305.0                 325.0                  16.0
# 2539                 326.0                 339.0                  18.0
# 2540                 311.0                 332.0                  14.0
# 2541                 366.0                 354.0                  23.0
#
#       sum_rolling10_GA_5v5  sum_rolling10_xGF_5v5  sum_rolling10_xGA_5v5  \
# 2537                  20.0                  16.43                  19.30
# 2538                  16.0                  16.69                  16.23
# 2539                  15.0                  14.83                  17.01
# 2540                  14.0                  15.10                  15.72
# 2541                  18.0                  19.91                  16.93
#
#       sum_rolling10_SF_5v5  last_10_FF%_5v5  last_10_GF%_5v5  \
# 2537                 237.0        48.542274        53.488372
# 2538                 208.0        48.412698        50.000000
# 2539                 223.0        49.022556        54.545455
# 2540                 230.0        48.367030        50.000000
# 2541                 259.0        50.833333        56.097561
#
#       last_10_xGF%_5v5  last_10_SH%    TOI_pk  xGA_pk    TOI_pp  xGF_pp  \
# 2537         45.983767     9.704641  1.516667    0.31  4.966667    0.44
# 2538         50.698663     7.692308  6.000000    0.14  2.000000    0.17
# 2539         46.576633     8.071749  2.000000    0.17  6.000000    0.14
# 2540         48.994160     6.086957  3.250000    0.28  1.250000    0.00
# 2541         54.044517     8.880309  1.250000    0.00  3.250000    0.28
#
#       sum_rolling10_TOI_pp  sum_rolling10_xGF_pp  last10_pp_TOI_per_game  \
# 2537             36.400000                  3.95                3.640000
# 2538             43.433333                  5.83                4.343333
# 2539             42.550000                  5.50                4.255000
# 2540             40.950000                  3.70                4.095000
# 2541             46.933333                  8.49                4.693333
#
#       last10_xGF_per_min_pp  sum_rolling10_TOI_pk  sum_rolling10_xGA_pk  \
# 2537               0.108516             49.466667                  3.25
# 2538               0.134229             53.866667                  6.04
# 2539               0.129260             44.216667                  3.97
# 2540               0.090354             51.616667                  3.99
# 2541               0.180895             42.350000                  5.35
#
#       last10_pk_TOI_per_game  last10_xGA_per_min_pk Last_Game_Date  \
# 2537                4.946667               0.065701     2018-04-05
# 2538                5.386667               0.112129     2018-04-06
# 2539                4.421667               0.089785     2018-04-05
# 2540                5.161667               0.077301     2018-04-05
# 2541                4.235000               0.126328     2018-04-05
#
#      Days_Since_Last_Game  B2B
# 2537               2 days    0
# 2538               1 days    1
# 2539               2 days    0
# 2540               2 days    0
# 2541               2 days    0

# %% [markdown]
# ### Get All Team Stats

# %%
primary1617 = get_and_format_nst_team_stats('20162017','5v5', 'n')
pp1617 = get_and_format_nst_team_stats('20162017','pp', 'n')
pk1617 = get_and_format_nst_team_stats('20162017','pk', 'n')

# %%
primary1718 = get_and_format_nst_team_stats('20172018','5v5', 'n')
pp1718 = get_and_format_nst_team_stats('20172018','pp', 'n')
pk1718 = get_and_format_nst_team_stats('20172018','pk', 'n')

# %%
features1617 = merge_team_stats(primary1617, pp1617, pk1617)
features1718 = merge_team_stats(primary1718, pp1718, pk1718)
features1819 = merge_team_stats(primary1819, pp1819, pk1819)
features1920 = merge_team_stats(primary1920, pp1920, pk1920)
features2021 = merge_team_stats(primary2021, pp2021, pk2021)

# %%
# 179       49.744115                   NaN                   NaN
# 241       47.948164                   NaN                   NaN
# 269       43.455497                   NaN                   NaN
# 297       45.686901                   NaN                   NaN
# 339       46.595745                   NaN                   NaN
# 355       49.163180                   NaN                   NaN
# 371       51.236400                   NaN                   NaN
# 399       48.864758                   NaN                   NaN
# 435       48.624754                   NaN                   NaN
# 457       50.308642                   NaN                   NaN
# 494       50.903614                   NaN                   NaN
# 545       51.177730                   NaN                   NaN
# 573       49.682875                   NaN                   NaN
# 615       52.115583                   NaN                   NaN
# 663       54.970760                   NaN                   NaN
#
#      last_20_FF%_5v5  sum_rolling10_TOI_5v5  sum_rolling10_FF_5v5  \
# 29               NaN                    NaN                   NaN
# 51               NaN                    NaN                   NaN
# 89               NaN                    NaN                   NaN
# 123              NaN                    NaN                   NaN
# 153              NaN                    NaN                   NaN
# 179              NaN                    NaN                   NaN
# 241              NaN                    NaN                   NaN
# 269              NaN                    NaN                   NaN
# 297              NaN                    NaN                   NaN
# 339              NaN                    NaN                   NaN
# 355              NaN             447.716667                 304.0
# 371              NaN             456.283333                 322.0
# 399              NaN             463.400000                 311.0
# 435              NaN             458.433333                 312.0
# 457              NaN             456.116667                 310.0
# 494              NaN             462.933333                 316.0
# 545              NaN             466.333333                 321.0
# 573              NaN             465.050000                 325.0
# 615              NaN             476.233333                 332.0
# 663              NaN             485.266667                 346.0
#
#      sum_rolling10_FA_5v5  sum_rolling10_GF_5v5  sum_rolling10_GA_5v5  \
# 29                    NaN                   NaN                   NaN
# 51                    NaN                   NaN                   NaN
# 89                    NaN                   NaN                   NaN
# 123                   NaN                   NaN                   NaN
# 153                   NaN                   NaN                   NaN
# 179                   NaN                   NaN                   NaN
# 241                   NaN                   NaN                   NaN
# 269                   NaN                   NaN                   NaN
# 297                   NaN                   NaN                   NaN
# 339                   NaN                   NaN                   NaN
# 355                 342.0                  22.0                  16.0
# 371                 332.0                  24.0                  19.0
# 399                 340.0                  25.0                  20.0
# 435                 338.0                  23.0                  21.0
# 457                 330.0                  22.0                  17.0
# 494                 336.0                  21.0                  20.0
# 545                 330.0                  21.0                  21.0
# 573                 322.0                  23.0                  23.0
# 615                 322.0                  24.0                  24.0
# 663                 320.0                  21.0                  26.0
#
#      sum_rolling10_xGF_5v5  sum_rolling10_xGA_5v5  sum_rolling10_SF_5v5  \
# 29                     NaN                    NaN                   NaN
# 51                     NaN                    NaN                   NaN
# 89                     NaN                    NaN                   NaN
# 123                    NaN                    NaN                   NaN
# 153                    NaN                    NaN                   NaN
# 179                    NaN                    NaN                   NaN
# 241                    NaN                    NaN                   NaN
# 269                    NaN                    NaN                   NaN
# 297                    NaN                    NaN                   NaN
# 339                    NaN                    NaN                   NaN
# 355                  15.30                  18.59                 208.0
# 371                  17.67                  18.50                 219.0
# 399                  17.30                  19.10                 217.0
# 435                  17.57                  18.79                 216.0
# 457                  17.75                  17.66                 211.0
# 494                  17.72                  19.05                 219.0
# 545                  18.11                  18.33                 221.0
# 573                  18.55                  17.55                 226.0
# 615                  17.84                  16.87                 231.0
# 494                    NaN      2017-11-07                3 days    0
# 545                    NaN      2017-11-10                4 days    0
# 573                    NaN      2017-11-14                2 days    0
# 615                    NaN      2017-11-16                3 days    0
# 663                    NaN      2017-11-19                3 days    0
#
# [20 rows x 104 columns]

# %%
pd.options.display.max_rows = 100
team_stats_all_seasons.isna().sum()
# Out:
# Game              0
# Team              0
# Unnamed: 2        0
# TOI               0
# CF                0
# CA                0
# CF%               0
# FF                0
# FA                0
# FF%               0
# SF                0
# SA                0
# SF%               0
# GF                0
# GA                0
# GF%             206
# xGF               0
# xGA               0
# xGF%             50
# SCF               0
# SCA               0
# SCF%              0
# HDCF              0
# HDCA              0
# HDCF%            50
# HDSF              0
# HDSA              0
# HDSF%            50
# HDGF              0
# HDGA              0
# HDGF%          1362
# HDSH%           101
# HDSV%           101
# MDCF              0
# MDCA              0
# MDCF%             0
# MDSF              0
# MDSA              0
# MDSF%             2
# MDGF              0
# MDGA              0
# MDGF%          4044
# MDSH%            44
# MDSV%            44
# LDCF              0
# LDCA              0
# LDCF%             0
# LDSF              0
# LDSA              0
# LDSF%             0
# LDGF              0
# LDGA              0
# LDGF%          6230
# LDSH%             3
# LDSV%             3
# SH%               0
# SV%               0
# PDO               0
# Attendance        0
# Date              0
# Game_Number       0
# Team_Key          0
# TOI_pk          228
# xGA_pk          228
# TOI_pp          228
# xGF_pp          228
# dtype: int64

# %%
for games in [3,5,10,20,30]:
    team_stats_all_seasons = calculate_team_features(team_stats_all_seasons, games)

# %%
team_stats_all_seasons.tail()
# Out:
#                                        Game Team                 Unnamed: 2  \
# 1511        2021-04-29 - Flyers 3, Devils 5  PHI  Limited ReportFull Report
# 1509        2021-04-29 - Sabres 2, Bruins 5  BUF  Limited ReportFull Report
# 1508        2021-04-29 - Sabres 2, Bruins 5  BOS  Limited ReportFull Report
# 1519  2021-04-29 - Panthers 4, Blackhawks 3  FLA  Limited ReportFull Report
# 1510        2021-04-29 - Flyers 3, Devils 5  N.J  Limited ReportFull Report
#
#         TOI  CF  CA    CF%  FF  FA    FF%  SF  SA    SF%  GF  GA    GF%   xGF  \
# 1511  50.10  46  31  59.74  33  22  60.00  20  13  60.61   1   2  33.33  1.68
# 1509  50.10  40  48  45.45  32  43  42.67  27  30  47.37   2   3  40.00  1.98
# 1508  50.10  48  40  54.55  43  32  57.33  30  27  52.63   3   2  60.00  1.57
# 1519  46.95  51  29  63.75  40  23  63.49  27  19  58.70   2   2  50.00  2.20
# 1510  50.10  31  46  40.26  22  33  40.00  13  20  39.39   2   1  66.67  1.19
#
#        xGA   xGF%  SCF  SCA   SCF%  HDCF  HDCA  HDCF%  HDSF  HDSA  HDSF%  \
# 1511  1.19  58.56   25   18  58.14     5     5  50.00     3     3  50.00
# 1509  1.57  55.75   22   16  57.89     7     8  46.67     7     6  53.85
# 1508  1.98  44.25   16   22  42.11     8     7  53.33     6     7  46.15
# 1519  1.30  62.91   24   11  68.57     7     5  58.33     5     5  50.00
# 1510  1.68  41.44   18   25  41.86     5     5  50.00     3     3  50.00
#
#       HDGF  HDGA  HDGF%  HDSH%  HDSV%  MDCF  MDCA  MDCF%  MDSF  MDSA  MDSF%  \
# 1511     1     1  50.00  33.33  66.67    20    13  60.61     7     3  70.00
# 1509     2     2  50.00  28.57  66.67    15     8  65.22     9     5  64.29
# 1508     2     2  50.00  33.33  71.43     8    15  34.78     5     9  35.71
# 1519     1     2  33.33  20.00  60.00    17     6  73.91     7     5  58.33
# 1510     1     1  50.00  33.33  66.67    13    20  39.39     3     7  30.00
#
#       MDGF  MDGA  MDGF%  MDSH%   MDSV%  LDCF  LDCA  LDCF%  LDSF  LDSA  LDSF%  \
# 1511     0     1    0.0   0.00   66.67    20    13  60.61     9     7  56.25
# 1509     0     1    0.0   0.00   80.00    16    30  34.78    10    17  37.04
# 1508     1     0  100.0  20.00  100.00    30    16  65.22    17    10  62.96
# 1519     1     0  100.0  14.29  100.00    25    16  60.98    14     9  60.87
# 1510     1     0  100.0  33.33  100.00    13    20  39.39     7     9  43.75
#
#       ...  last_10_xGF%_5v5  last_10_SH%  sum_rolling10_TOI_pp  \
# 1511  ...         49.882145     6.048387             40.150000
# 1509  ...         46.831337     6.923077             53.616667
# 1508  ...         59.129173     8.041958             45.983333
# 1519  ...         57.146845     7.067138             66.150000
# 1510  ...         51.397558     7.725322             48.816667
#
#       sum_rolling10_xGF_pp  last10_pp_TOI_per_game  last10_xGF_per_min_pp  \
# 1511                  5.62                4.015000               0.139975
# 1509                  4.06                5.361667               0.075723
# 1508                  3.32                4.598333               0.072200
# 1519                  6.01                6.615000               0.090854
# 1510                  5.36                4.881667               0.109799
#
#       sum_rolling10_TOI_pk  sum_rolling10_xGA_pk  last10_pk_TOI_per_game  \
# 1511             51.966667                  5.17                5.196667
# 1509             36.600000                  5.59                3.660000
# 1508             68.583333                  6.43                6.858333
# 1519             38.200000                  4.13                3.820000
# 1510             31.300000                  3.50                3.130000
#
#      last10_xGA_per_min_pk  sum_rolling20_TOI_5v5 sum_rolling20_FF_5v5  \
# 1511              0.099487             985.616667                701.0
# 1509              0.152732             977.350000                642.0
# 1508              0.093755             945.433333                729.0
# 1519              0.108115             950.083333                700.0
# 1510              0.111821             992.366667                676.0
#
#       sum_rolling20_FA_5v5  sum_rolling20_GF_5v5  sum_rolling20_GA_5v5  \
# 1511                 604.0                  29.0                  43.0
# 1509                 804.0                  37.0                  44.0
# 1508                 600.0                  42.0                  35.0
# 1519                 592.0                  37.0                  33.0
# 1510                 647.0                  40.0                  54.0
#
#       sum_rolling20_xGF_5v5  sum_rolling20_xGA_5v5  sum_rolling20_SF_5v5  \
# 1511                  34.97                  32.90                 521.0
# 1509                  35.41                  42.34                 495.0
# 1508                  35.77                  30.12                 548.0
# 1519                  39.34                  34.09                 534.0
# 1510                  38.55                  34.52                 468.0
#
#       last_20_FF%_5v5  last_20_GF%_5v5  last_20_xGF%_5v5  last_20_SH%  \
# 1511        53.716475        40.277778         51.524974     5.566219
# 1509        44.398340        45.679012         45.543408     7.474747
# 1508        54.853273        54.545455         54.287449     7.664234
# 1519        54.179567        52.857143         53.574833     6.928839
# 1510        51.095994        42.553191         52.757630     8.547009
#
#       sum_rolling20_TOI_pp  sum_rolling20_xGF_pp  last20_pp_TOI_per_game  \
# 1511             89.766667                 11.72                4.488333
# 1509             95.216667                  7.09                4.760833
# 1508            102.383333                  8.54                5.119167
# 1519            126.300000                 12.59                6.315000
# 1510            102.033333                 11.45                5.101667
#
#       last20_xGF_per_min_pp  sum_rolling20_TOI_pk  sum_rolling20_xGA_pk  \
# 1511               0.130561            103.766667                  9.97
# 1509               0.074462             91.316667                 11.99
# 1508               0.083412            117.666667                  9.77
# 1519               0.099683             88.483333                 10.63
# 1510               0.112218             77.533333                 10.62
#
#       last20_pk_TOI_per_game  last20_xGA_per_min_pk  sum_rolling30_TOI_5v5  \
# 1511                5.188333               0.096081            1460.466667
# 1509                4.565833               0.131301            1492.183333
# 1508                5.883333               0.083031            1423.750000
# 1519                4.424167               0.120136            1406.050000
# 1510                3.876667               0.136973            1468.583333
#
#       sum_rolling30_FF_5v5  sum_rolling30_FA_5v5  sum_rolling30_GF_5v5  \
# 1511                1005.0                 870.0                  47.0
# 1509                 945.0                1171.0                  53.0
# 1508                1058.0                 895.0                  55.0
# 1519                1019.0                 907.0                  59.0
# 1510                1003.0                 990.0                  60.0
#
#       sum_rolling30_GA_5v5  sum_rolling30_xGF_5v5 sum_rolling30_xGA_5v5  \
# 1511                  82.0                  50.03                 48.32
# 1509                  76.0                  52.51                 64.06
# 1508                  46.0                  49.38                 45.18
# 1519                  54.0                  58.57                 51.79
# 1510                  75.0                  55.72                 53.49
#
#      sum_rolling30_SF_5v5  last_30_FF%_5v5  last_30_GF%_5v5  last_30_xGF%_5v5  \
# 1511                746.0        53.600000        36.434109         50.869344
# 1509                698.0        44.659735        41.085271         45.045895
# 1508                788.0        54.173067        54.455446         52.220812
# 1519                780.0        52.907580        52.212389         53.071765
# 1510                708.0        50.326141        44.444444         51.020969
#
#       last_30_SH%  sum_rolling30_TOI_pp  sum_rolling30_xGF_pp  \
# 1511     6.300268            150.533333                 16.17
# 1509     7.593123            122.783333                  8.39
# 1508     6.979695            154.966667                 12.35
# 1519     7.564103            193.533333                 20.46
# 1510     8.474576            146.966667                 14.75
#
#       last30_pp_TOI_per_game  last30_xGF_per_min_pp  sum_rolling30_TOI_pk  \
# 1511                5.017778               0.107418            142.083333
# 1509                4.092778               0.068332            136.633333
# 1508                5.165556               0.079695            171.583333
# 1519                6.451111               0.105718            144.850000
# 1510                4.898889               0.100363            136.383333
#
#       sum_rolling30_xGA_pk  last30_pk_TOI_per_game  last30_xGA_per_min_pk
# 1511                 14.13                4.736111               0.099449
# 1509                 17.86                4.554444               0.130715
# 1508                 14.90                5.719444               0.086838
# 1519                 15.11                4.828333               0.104315
# 1510                 16.68                4.546111               0.122302
#
# [5 rows x 169 columns]

# %%
team_stats_all_seasons.isna().sum()[team_stats_all_seasons.isna().sum() >100]
# Out:
# GF%                        206
# HDGF%                     1362
# HDSH%                      101
# HDSV%                      101
# MDGF%                     4044
# LDGF%                     6230
# sum_rolling5_TOI_5v5       155
# sum_rolling5_FF_5v5        155
# sum_rolling5_FA_5v5        155
# sum_rolling5_GF_5v5        155
# sum_rolling5_GA_5v5        155
# sum_rolling5_xGF_5v5       155
# sum_rolling5_xGA_5v5       155
# sum_rolling5_SF_5v5        155
# last_5_FF%_5v5             155
# last_5_GF%_5v5             155
# last_5_xGF%_5v5            155
# last_5_SH%                 155
# sum_rolling5_TOI_pp        155
# sum_rolling5_xGF_pp        155
# last5_pp_TOI_per_game      155
# last5_xGF_per_min_pp       155
# sum_rolling5_TOI_pk        155
# sum_rolling5_xGA_pk        155
# last5_pk_TOI_per_game      155
# last5_xGA_per_min_pk       155
# sum_rolling10_TOI_5v5      310
# sum_rolling10_FF_5v5       310
# sum_rolling10_FA_5v5       310
# sum_rolling10_GF_5v5       310
# sum_rolling10_GA_5v5       310
# sum_rolling10_xGF_5v5      310
# sum_rolling10_xGA_5v5      310
# sum_rolling10_SF_5v5       310
# last_10_FF%_5v5            310
# last_10_GF%_5v5            310
# last_10_xGF%_5v5           310
# last_10_SH%                310
# sum_rolling10_TOI_pp       310
# sum_rolling10_xGF_pp       310
# last10_pp_TOI_per_game     310
# last10_xGF_per_min_pp      310
# sum_rolling10_TOI_pk       310
# sum_rolling10_xGA_pk       310
# last10_pk_TOI_per_game     310
# last10_xGA_per_min_pk      310
# sum_rolling20_TOI_5v5      620
# sum_rolling20_FF_5v5       620
# sum_rolling20_FA_5v5       620
# sum_rolling20_GF_5v5       620
# sum_rolling20_GA_5v5       620
# sum_rolling20_xGF_5v5      620
# sum_rolling20_xGA_5v5      620
# sum_rolling20_SF_5v5       620
# last_20_FF%_5v5            620
# last_20_GF%_5v5            620
# last_20_xGF%_5v5           620
# last_20_SH%                620
# sum_rolling20_TOI_pp       620
# sum_rolling20_xGF_pp       620
# last20_pp_TOI_per_game     620
# last20_xGF_per_min_pp      620
# sum_rolling20_TOI_pk       620
# sum_rolling20_xGA_pk       620
# last20_pk_TOI_per_game     620
# last20_xGA_per_min_pk      620
# sum_rolling30_TOI_5v5      930
# sum_rolling30_FF_5v5       930
# sum_rolling30_FA_5v5       930
# sum_rolling30_GF_5v5       930
# sum_rolling30_GA_5v5       930
# sum_rolling30_xGF_5v5      930
# sum_rolling30_xGA_5v5      930
# sum_rolling30_SF_5v5       930
# last_30_FF%_5v5            930
# last_30_GF%_5v5            930
# last_30_xGF%_5v5           930
# last_30_SH%                930
# sum_rolling30_TOI_pp       930
# sum_rolling30_xGF_pp       930
# last30_pp_TOI_per_game     930
# last30_xGF_per_min_pp      930
# sum_rolling30_TOI_pk       930
# sum_rolling30_xGA_pk       930
# last30_pk_TOI_per_game     930
# last30_xGA_per_min_pk      930
# dtype: int64

# %%
list(team_stats_all_seasons.columns)
# Out:
# ['Game',
#  'Team',
#  'Unnamed: 2',
#  'TOI',
#  'CF',
#  'CA',
#  'CF%',
#  'FF',
#  'FA',
#  'FF%',
#  'SF',
#  'SA',
#  'SF%',
#  'GF',
#  'GA',
#  'GF%',
#  'xGF',
#  'xGA',
#  'xGF%',
#  'SCF',
#  'SCA',
#  'SCF%',
#  'HDCF',
#  'HDCA',
#  'HDCF%',
#  'HDSF',
#  'HDSA',
#  'HDSF%',
#  'HDGF',
#  'HDGA',
#  'HDGF%',
#  'HDSH%',
#  'HDSV%',
#  'MDCF',
#  'MDCA',
#  'MDCF%',
#  'MDSF',
#  'MDSA',
#  'MDSF%',
#  'MDGF',
#  'MDGA',
#  'MDGF%',
#  'MDSH%',
#  'MDSV%',
#  'LDCF',
#  'LDCA',
#  'LDCF%',
#  'LDSF',
#  'LDSA',
#  'LDSF%',
#  'LDGF',
#  'LDGA',
#  'LDGF%',
#  'LDSH%',
#  'LDSV%',
#  'SH%',
#  'SV%',
#  'PDO',
#  'Attendance',
#  'Date',
#  'Game_Number',
#  'Team_Key',
#  'TOI_pk',
#  'xGA_pk',
#  'TOI_pp',
#  'xGF_pp',
#  'sum_rolling3_TOI_5v5',
#  'sum_rolling3_FF_5v5',
#  'sum_rolling3_FA_5v5',
#  'sum_rolling3_GF_5v5',
#  'sum_rolling3_GA_5v5',
#  'sum_rolling3_xGF_5v5',
#  'sum_rolling3_xGA_5v5',
#  'sum_rolling3_SF_5v5',
#  'last_3_FF%_5v5',
#  'last_3_GF%_5v5',
#  'last_3_xGF%_5v5',
#  'last_3_SH%',
#  'sum_rolling3_TOI_pp',
#  'sum_rolling3_xGF_pp',
#  'last3_pp_TOI_per_game',
#  'last3_xGF_per_min_pp',
#  'sum_rolling3_TOI_pk',
#  'sum_rolling3_xGA_pk',
#  'last3_pk_TOI_per_game',
#  'last3_xGA_per_min_pk',
#  'Last_Game_Date',
#  'Days_Since_Last_Game',
#  'B2B',
#  'sum_rolling5_TOI_5v5',
#  'sum_rolling5_FF_5v5',
#  'sum_rolling5_FA_5v5',
#  'sum_rolling5_GF_5v5',
#  'sum_rolling5_GA_5v5',
#  'sum_rolling5_xGF_5v5',
#  'sum_rolling5_xGA_5v5',
#  'sum_rolling5_SF_5v5',
#  'last_5_FF%_5v5',
#  'last_5_GF%_5v5',
#  'last_5_xGF%_5v5',
#  'last_5_SH%',
#  'sum_rolling5_TOI_pp',
#  'sum_rolling5_xGF_pp',
#  'last5_pp_TOI_per_game',
#  'last5_xGF_per_min_pp',
#  'sum_rolling5_TOI_pk',
#  'sum_rolling5_xGA_pk',
#  'last5_pk_TOI_per_game',
#  'last5_xGA_per_min_pk',
#  'sum_rolling10_TOI_5v5',
#  'sum_rolling10_FF_5v5',
#  'sum_rolling10_FA_5v5',
#  'sum_rolling10_GF_5v5',
#  'sum_rolling10_GA_5v5',
#  'sum_rolling10_xGF_5v5',
#  'sum_rolling10_xGA_5v5',
#  'sum_rolling10_SF_5v5',
#  'last_10_FF%_5v5',
#  'last_10_GF%_5v5',
#  'last_10_xGF%_5v5',
#  'last_10_SH%',
#  'sum_rolling10_TOI_pp',
#  'sum_rolling10_xGF_pp',
#  'last10_pp_TOI_per_game',
#  'last10_xGF_per_min_pp',
#  'sum_rolling10_TOI_pk',
#  'sum_rolling10_xGA_pk',
#  'last10_pk_TOI_per_game',
#  'last10_xGA_per_min_pk',
#  'sum_rolling20_TOI_5v5',
#  'sum_rolling20_FF_5v5',
#  'sum_rolling20_FA_5v5',
#  'sum_rolling20_GF_5v5',
#  'sum_rolling20_GA_5v5',
#  'sum_rolling20_xGF_5v5',
#  'sum_rolling20_xGA_5v5',
#  'sum_rolling20_SF_5v5',
#  'last_20_FF%_5v5',
#  'last_20_GF%_5v5',
#  'last_20_xGF%_5v5',
#  'last_20_SH%',
#  'sum_rolling20_TOI_pp',
#  'sum_rolling20_xGF_pp',
#  'last20_pp_TOI_per_game',
#  'last20_xGF_per_min_pp',
#  'sum_rolling20_TOI_pk',
#  'sum_rolling20_xGA_pk',
#  'last20_pk_TOI_per_game',
#  'last20_xGA_per_min_pk',
#  'sum_rolling30_TOI_5v5',
#  'sum_rolling30_FF_5v5',
#  'sum_rolling30_FA_5v5',
#  'sum_rolling30_GF_5v5',
#  'sum_rolling30_GA_5v5',
#  'sum_rolling30_xGF_5v5',
#  'sum_rolling30_xGA_5v5',
#  'sum_rolling30_SF_5v5',
#  'last_30_FF%_5v5',
#  'last_30_GF%_5v5',
#  'last_30_xGF%_5v5',
#  'last_30_SH%',
#  'sum_rolling30_TOI_pp',
#  'sum_rolling30_xGF_pp',
#  'last30_pp_TOI_per_game',
#  'last30_xGF_per_min_pp',
#  'sum_rolling30_TOI_pk',
#  'sum_rolling30_xGA_pk',
#  'last30_pk_TOI_per_game',
#  'last30_xGA_per_min_pk']

# %%
feature_columns_all_seasons = ['Team_Key',
 'last_3_FF%_5v5',
 'last_3_GF%_5v5',
 'last_3_xGF%_5v5',
 'last_3_SH%',
 'last3_pp_TOI_per_game',
 'last3_xGF_per_min_pp',
 'last3_pk_TOI_per_game',
 'last3_xGA_per_min_pk',
 'B2B',
 'last_5_FF%_5v5',
 'last_5_GF%_5v5',
 'last_5_xGF%_5v5',
 'last_5_SH%',
 'last5_pp_TOI_per_game',
 'last5_xGF_per_min_pp',
 'last5_pk_TOI_per_game',
 'last5_xGA_per_min_pk',
 'last_10_FF%_5v5',
 'last_10_GF%_5v5',
 'last_10_xGF%_5v5',
 'last_10_SH%',
 'last10_pp_TOI_per_game',
 'last10_xGF_per_min_pp',
 'last10_pk_TOI_per_game',
 'last10_xGA_per_min_pk',
 'last_20_FF%_5v5',
 'last_20_GF%_5v5',
 'last_20_xGF%_5v5',
 'last_20_SH%',
 'last20_pp_TOI_per_game',
 'last20_xGF_per_min_pp',
 'last20_pk_TOI_per_game',
 'last20_xGA_per_min_pk',
 'last_30_FF%_5v5',
 'last_30_GF%_5v5',
 'last_30_xGF%_5v5',
 'last_30_SH%',
 'last30_pp_TOI_per_game',
 'last30_xGF_per_min_pp',
 'last30_pk_TOI_per_game',
 'last30_xGA_per_min_pk']

# %%
df_20172018_B = merge_starters_and_features(results, goalie_features_dfB, team_stats_all_seasons, feature_columns_all_seasons, goalie_feature_columns)
df_20182019_B = merge_starters_and_features(results1819, goalie_features_dfB, team_stats_all_seasons, feature_columns_all_seasons, goalie_feature_columns)
df_20192020_B = merge_starters_and_features(results1920, goalie_features_dfB, team_stats_all_seasons, feature_columns_all_seasons, goalie_feature_columns)
df_20202021_B = merge_starters_and_features(results2021, goalie_features_dfB, team_stats_all_seasons, feature_columns_all_seasons, goalie_feature_columns)

# %%
all_games_multirolling_noSVA = pd.concat([df_20172018_B, df_20182019_B, df_20192020_B, df_20202021_B])

# %%
#impute goalie stats where lack of games causing NaN
all_games_multirolling_noSVA['away_Last_20_FenwickSV%'] = np.where(all_games_multirolling_noSVA['away_Last_20_FenwickSV%'].isna(), ig_FenwickSV,all_games_multirolling_noSVA['away_Last_20_FenwickSV%'])
all_games_multirolling_noSVA['away_Last_20_GSAx/60'] = np.where(all_games_multirolling_noSVA['away_Last_20_GSAx/60'].isna(), ig_GSAx60, all_games_multirolling_noSVA['away_Last_20_GSAx/60'])
all_games_multirolling_noSVA['away_Last_20_HDCSV%'] = np.where(all_games_multirolling_noSVA['away_Last_20_HDCSV%'].isna(), ig_HDCSV, all_games_multirolling_noSVA['away_Last_20_HDCSV%'])
all_games_multirolling_noSVA['home_Last_20_FenwickSV%'] = np.where(all_games_multirolling_noSVA['home_Last_20_FenwickSV%'].isna(), ig_FenwickSV,all_games_multirolling_noSVA['home_Last_20_FenwickSV%'])
all_games_multirolling_noSVA['home_Last_20_GSAx/60'] = np.where(all_games_multirolling_noSVA['home_Last_20_GSAx/60'].isna(), ig_GSAx60, all_games_multirolling_noSVA['home_Last_20_GSAx/60'])
all_games_multirolling_noSVA['home_Last_20_HDCSV%'] = np.where(all_games_multirolling_noSVA['home_Last_20_HDCSV%'].isna(), ig_HDCSV, all_games_multirolling_noSVA['home_Last_20_HDCSV%'])

# %%
all_games_multirolling_noSVA.to_csv('data/all_games_multirolling_noSVA.csv')

# %%
pd.options.display.max_rows = 104
all_games_multirolling_noSVA.isna().sum()
# Out:
# game_id                         0
# date                            0
# venue                           0
# home_team                       0
# away_team                       0
# start_time                      0
# home_score                      0
# away_score                      0
# status                          0
# Home_Team_Won                   0
# Home_Team_Key                   0
# Away_Team_Key                   0
# home_goalie                    12
# home_Last_20_FenwickSV%         0
# home_Last_20_GSAx/60            0
# home_Last_20_HDCSV%             0
# away_goalie                    16
# away_Last_20_FenwickSV%         0
# away_Last_20_GSAx/60            0
# away_Last_20_HDCSV%             0
# home_Team_Key                   3
# home_last_3_FF%_5v5             4
# home_last_3_GF%_5v5             5
# home_last_3_xGF%_5v5            4
# home_last_3_SH%                 4
# home_last3_pp_TOI_per_game      4
# home_last3_xGF_per_min_pp       4
# home_last3_pk_TOI_per_game      4
# home_last3_xGA_per_min_pk       4
# home_B2B                        3
# home_last_5_FF%_5v5             6
# home_last_5_GF%_5v5             6
# home_last_5_xGF%_5v5            6
# home_last_5_SH%                 6
# home_last5_pp_TOI_per_game      6
# home_last5_xGF_per_min_pp       6
# home_last5_pk_TOI_per_game      6
# home_last5_xGA_per_min_pk       6
# home_last_10_FF%_5v5           10
# home_last_10_GF%_5v5           10
# home_last_10_xGF%_5v5          10
# home_last_10_SH%               10
# home_last10_pp_TOI_per_game    10
# home_last10_xGF_per_min_pp     10
# home_last10_pk_TOI_per_game    10
# home_last10_xGA_per_min_pk     10
# home_last_20_FF%_5v5           12
# home_last_20_GF%_5v5           12
# home_last_20_xGF%_5v5          12
# home_last_20_SH%               12
# home_last20_pp_TOI_per_game    12
# home_last20_xGF_per_min_pp     12
# home_last20_pk_TOI_per_game    12
# home_last20_xGA_per_min_pk     12
# home_last_30_FF%_5v5           17
# home_last_30_GF%_5v5           17
# home_last_30_xGF%_5v5          17
# home_last_30_SH%               17
# home_last30_pp_TOI_per_game    17
# home_last30_xGF_per_min_pp     17
# home_last30_pk_TOI_per_game    17
# home_last30_xGA_per_min_pk     17
# away_Team_Key                   3
# away_last_3_FF%_5v5             5
# away_last_3_GF%_5v5             5
# away_last_3_xGF%_5v5            5
# away_last_3_SH%                 5
# away_last3_pp_TOI_per_game      5
# away_last3_xGF_per_min_pp       5
# away_last3_pk_TOI_per_game      5
# away_last3_xGA_per_min_pk       5
# away_B2B                        3
# away_last_5_FF%_5v5             5
# away_last_5_GF%_5v5             5
# away_last_5_xGF%_5v5            5
# away_last_5_SH%                 5
# away_last5_pp_TOI_per_game      5
# away_last5_xGF_per_min_pp       5
# away_last5_pk_TOI_per_game      5
# away_last5_xGA_per_min_pk       5
# away_last_10_FF%_5v5            6
# away_last_10_GF%_5v5            6
# away_last_10_xGF%_5v5           6
# away_last_10_SH%                6
# away_last10_pp_TOI_per_game     6
# away_last10_xGF_per_min_pp      6
# away_last10_pk_TOI_per_game     6
# away_last10_xGA_per_min_pk      6
# away_last_20_FF%_5v5           15
# away_last_20_GF%_5v5           15
# away_last_20_xGF%_5v5          15
# away_last_20_SH%               15
# away_last20_pp_TOI_per_game    15
# away_last20_xGF_per_min_pp     15
# away_last20_pk_TOI_per_game    15
# away_last20_xGA_per_min_pk     15
# away_last_30_FF%_5v5           20
# away_last_30_GF%_5v5           20
# away_last_30_xGF%_5v5          20
# away_last_30_SH%               20
# away_last30_pp_TOI_per_game    20
# away_last30_xGF_per_min_pp     20
# away_last30_pk_TOI_per_game    20
# away_last30_xGA_per_min_pk     20
# dtype: int64

# %% [markdown]
# ### Getting Data With Scoring and Venue Adjustments

# %%
#scraping team stats from NST
sequence = [x/10 for x in range(60, 120)]
time.sleep(random.choice(sequence))

primarysva1617 = get_and_format_nst_team_stats('20162017', 'sva', 'n')
primarysva1718 = get_and_format_nst_team_stats('20172018','sva', 'n')
primarysva1819 = get_and_format_nst_team_stats('20182019','sva', 'n')
primarysva1920 = get_and_format_nst_team_stats('20192020','sva', 'n')
primarysva2021 = get_and_format_nst_team_stats('20202021','sva', 'n')

time.sleep(random.choice(sequence))

pp1617 = get_and_format_nst_team_stats('20162017','pp', 'n')
pp1718 = get_and_format_nst_team_stats('20172018','pp', 'n')
pp1819 = get_and_format_nst_team_stats('20182019','pp', 'n')
pp1920 = get_and_format_nst_team_stats('20192020','pp', 'n')
pp2021 = get_and_format_nst_team_stats('20202021','pp', 'n')

time.sleep(random.choice(sequence))

pk1617 = get_and_format_nst_team_stats('20162017','pk', 'n')
pk1718 = get_and_format_nst_team_stats('20172018','pk', 'n')
pk1819 = get_and_format_nst_team_stats('20182019','pk', 'n')
pk1920 = get_and_format_nst_team_stats('20192020','pk', 'n')
pk2021 = get_and_format_nst_team_stats('20202021','pk', 'n')

# %%
#merge features for each season
featuressva1617 = merge_team_stats(primarysva1617, pp1617, pk1617)
featuressva1718 = merge_team_stats(primarysva1718, pp1718, pk1718)
featuressva1819 = merge_team_stats(primarysva1819, pp1819, pk1819)
featuressva1920 = merge_team_stats(primarysva1920, pp1920, pk1920)
featuressva2021 = merge_team_stats(primarysva2021, pp2021, pk2021)

# %%
#concat each season into one df
team_stats_all_seasons_sva = pd.concat([featuressva1617, featuressva1718, featuressva1819, featuressva1920, featuressva2021]).sort_values('Date')

# %%
#calculate different rolling game features
for games in [3,5,10,20,30,40]:
    team_stats_all_seasons_sva = calculate_team_features(team_stats_all_seasons_sva, games)

# %%
list(team_stats_all_seasons_sva.columns)
# Out:
# ['Game',
#  'Team',
#  'Unnamed: 2',
#  'TOI',
#  'CF',
#  'CA',
#  'CF%',
#  'FF',
#  'FA',
#  'FF%',
#  'SF',
#  'SA',
#  'SF%',
#  'GF',
#  'GA',
#  'GF%',
#  'xGF',
#  'xGA',
#  'xGF%',
#  'SCF',
#  'SCA',
#  'SCF%',
#  'HDCF',
#  'HDCA',
#  'HDCF%',
#  'HDSF',
#  'HDSA',
#  'HDSF%',
#  'HDGF',
#  'HDGA',
#  'HDGF%',
#  'HDSH%',
#  'HDSV%',
#  'MDCF',
#  'MDCA',
#  'MDCF%',
#  'MDSF',
#  'MDSA',
#  'MDSF%',
#  'MDGF',
#  'MDGA',
#  'MDGF%',
#  'MDSH%',
#  'MDSV%',
#  'LDCF',
#  'LDCA',
#  'LDCF%',
#  'LDSF',
#  'LDSA',
#  'LDSF%',
#  'LDGF',
#  'LDGA',
#  'LDGF%',
#  'LDSH%',
#  'LDSV%',
#  'SH%',
#  'SV%',
#  'PDO',
#  'Attendance',
#  'Date',
#  'Game_Number',
#  'Team_Key',
#  'TOI_pk',
#  'xGA_pk',
#  'GA_pk',
#  'TOI_pp',
#  'xGF_pp',
#  'GF_pp',
#  'sum_rolling3_TOI_5v5',
#  'sum_rolling3_FF_5v5',
#  'sum_rolling3_FA_5v5',
#  'sum_rolling3_GF_5v5',
#  'sum_rolling3_GA_5v5',
#  'sum_rolling3_xGF_5v5',
#  'sum_rolling3_xGA_5v5',
#  'sum_rolling3_SF_5v5',
#  'last_3_FF%_5v5',
#  'last_3_GF%_5v5',
#  'last_3_xGF%_5v5',
#  'last_3_SH%',
#  'sum_rolling3_TOI_pp',
#  'sum_rolling3_xGF_pp',
#  'sum_rolling3_GF_pp',
#  'last3_pp_TOI_per_game',
#  'last3_xGF_per_min_pp',
#  'last3_GF_per_min_pp',
#  'sum_rolling3_TOI_pk',
#  'sum_rolling3_xGA_pk',
#  'sum_rolling3_GA_pk',
#  'last3_pk_TOI_per_game',
#  'last3_xGA_per_min_pk',
#  'last3_GA_per_min_pk',
#  'Last_Game_Date',
#  'Days_Since_Last_Game',
#  'B2B',
#  'Season',
#  'sum_rolling5_TOI_5v5',
#  'sum_rolling5_FF_5v5',
#  'sum_rolling5_FA_5v5',
#  'sum_rolling5_GF_5v5',
#  'sum_rolling5_GA_5v5',
#  'sum_rolling5_xGF_5v5',
#  'sum_rolling5_xGA_5v5',
#  'sum_rolling5_SF_5v5',
#  'last_5_FF%_5v5',
#  'last_5_GF%_5v5',
#  'last_5_xGF%_5v5',
#  'last_5_SH%',
#  'sum_rolling5_TOI_pp',
#  'sum_rolling5_xGF_pp',
#  'sum_rolling5_GF_pp',
#  'last5_pp_TOI_per_game',
#  'last5_xGF_per_min_pp',
#  'last5_GF_per_min_pp',
#  'sum_rolling5_TOI_pk',
#  'sum_rolling5_xGA_pk',
#  'sum_rolling5_GA_pk',
#  'last5_pk_TOI_per_game',
#  'last5_xGA_per_min_pk',
#  'last5_GA_per_min_pk',
#  'sum_rolling10_TOI_5v5',
#  'sum_rolling10_FF_5v5',
#  'sum_rolling10_FA_5v5',
#  'sum_rolling10_GF_5v5',
#  'sum_rolling10_GA_5v5',
#  'sum_rolling10_xGF_5v5',
#  'sum_rolling10_xGA_5v5',
#  'sum_rolling10_SF_5v5',
#  'last_10_FF%_5v5',
#  'last_10_GF%_5v5',
#  'last_10_xGF%_5v5',
#  'last_10_SH%',
#  'sum_rolling10_TOI_pp',
#  'sum_rolling10_xGF_pp',
#  'sum_rolling10_GF_pp',
#  'last10_pp_TOI_per_game',
#  'last10_xGF_per_min_pp',
#  'last10_GF_per_min_pp',
#  'sum_rolling10_TOI_pk',
#  'sum_rolling10_xGA_pk',
#  'sum_rolling10_GA_pk',
#  'last10_pk_TOI_per_game',
#  'last10_xGA_per_min_pk',
#  'last10_GA_per_min_pk',
#  'sum_rolling20_TOI_5v5',
#  'sum_rolling20_FF_5v5',
#  'sum_rolling20_FA_5v5',
#  'sum_rolling20_GF_5v5',
#  'sum_rolling20_GA_5v5',
#  'sum_rolling20_xGF_5v5',
#  'sum_rolling20_xGA_5v5',
#  'sum_rolling20_SF_5v5',
#  'last_20_FF%_5v5',
#  'last_20_GF%_5v5',
#  'last_20_xGF%_5v5',
#  'last_20_SH%',
#  'sum_rolling20_TOI_pp',
#  'sum_rolling20_xGF_pp',
#  'sum_rolling20_GF_pp',
#  'last20_pp_TOI_per_game',
#  'last20_xGF_per_min_pp',
#  'last20_GF_per_min_pp',
#  'sum_rolling20_TOI_pk',
#  'sum_rolling20_xGA_pk',
#  'sum_rolling20_GA_pk',
#  'last20_pk_TOI_per_game',
#  'last20_xGA_per_min_pk',
#  'last20_GA_per_min_pk',
#  'sum_rolling30_TOI_5v5',
#  'sum_rolling30_FF_5v5',
#  'sum_rolling30_FA_5v5',
#  'sum_rolling30_GF_5v5',
#  'sum_rolling30_GA_5v5',
#  'sum_rolling30_xGF_5v5',
#  'sum_rolling30_xGA_5v5',
#  'sum_rolling30_SF_5v5',
#  'last_30_FF%_5v5',
#  'last_30_GF%_5v5',
#  'last_30_xGF%_5v5',
#  'last_30_SH%',
#  'sum_rolling30_TOI_pp',
#  'sum_rolling30_xGF_pp',
#  'sum_rolling30_GF_pp',
#  'last30_pp_TOI_per_game',
#  'last30_xGF_per_min_pp',
#  'last30_GF_per_min_pp',
#  'sum_rolling30_TOI_pk',
#  'sum_rolling30_xGA_pk',
#  'sum_rolling30_GA_pk',
#  'last30_pk_TOI_per_game',
#  'last30_xGA_per_min_pk',
#  'last30_GA_per_min_pk',
#  'sum_rolling40_TOI_5v5',
#  'sum_rolling40_FF_5v5',
#  'sum_rolling40_FA_5v5',
#  'sum_rolling40_GF_5v5',
#  'sum_rolling40_GA_5v5',
#  'sum_rolling40_xGF_5v5',
#  'sum_rolling40_xGA_5v5',
#  'sum_rolling40_SF_5v5',
#  'last_40_FF%_5v5',
#  'last_40_GF%_5v5',
#  'last_40_xGF%_5v5',
#  'last_40_SH%',
#  'sum_rolling40_TOI_pp',
#  'sum_rolling40_xGF_pp',
#  'sum_rolling40_GF_pp',
#  'last40_pp_TOI_per_game',
#  'last40_xGF_per_min_pp',
#  'last40_GF_per_min_pp',
#  'sum_rolling40_TOI_pk',
#  'sum_rolling40_xGA_pk',
#  'sum_rolling40_GA_pk',
#  'last40_pk_TOI_per_game',
#  'last40_xGA_per_min_pk',
#  'last40_GA_per_min_pk']

# %%
feature_columns_all_seasons = [
 'Game_Number',
 'Team_Key',
 'last_3_FF%_5v5',
 'last_3_GF%_5v5',
 'last_3_xGF%_5v5',
 'last_3_SH%',
 'last3_pp_TOI_per_game',
 'last3_xGF_per_min_pp',
 'last3_GF_per_min_pp',
 'last3_pk_TOI_per_game',
 'last3_xGA_per_min_pk',
 'last3_GA_per_min_pk',
 'Last_Game_Date',
 'Days_Since_Last_Game',
 'B2B',
 'last_5_FF%_5v5',
 'last_5_GF%_5v5',
 'last_5_xGF%_5v5',
 'last_5_SH%',
 'last5_pp_TOI_per_game',
 'last5_xGF_per_min_pp',
 'last5_GF_per_min_pp',
 'last5_pk_TOI_per_game',
 'last5_xGA_per_min_pk',
 'last5_GA_per_min_pk',
 'last_10_FF%_5v5',
 'last_10_GF%_5v5',
 'last_10_xGF%_5v5',
 'last_10_SH%',
 'last10_pp_TOI_per_game',
 'last10_xGF_per_min_pp',
 'last10_GF_per_min_pp',
 'last10_pk_TOI_per_game',
 'last10_xGA_per_min_pk',
 'last10_GA_per_min_pk',
 'last_20_FF%_5v5',
 'last_20_GF%_5v5',
 'last_20_xGF%_5v5',
 'last_20_SH%',
 'last20_pp_TOI_per_game',
 'last20_xGF_per_min_pp',
 'last20_GF_per_min_pp',
 'last20_pk_TOI_per_game',
 'last20_xGA_per_min_pk',
 'last20_GA_per_min_pk',
 'last_30_FF%_5v5',
 'last_30_GF%_5v5',
 'last_30_xGF%_5v5',
 'last_30_SH%',
 'last30_pp_TOI_per_game',
 'last30_xGF_per_min_pp',
 'last30_GF_per_min_pp',
 'last30_pk_TOI_per_game',
 'last30_xGA_per_min_pk',
 'last30_GA_per_min_pk',
 'last_40_FF%_5v5',
 'last_40_GF%_5v5',
 'last_40_xGF%_5v5',
 'last_40_SH%',
 'last40_pp_TOI_per_game',
 'last40_xGF_per_min_pp',
 'last40_GF_per_min_pp',
 'last40_pk_TOI_per_game',
 'last40_xGA_per_min_pk',
 'last40_GA_per_min_pk']

# %%
#get official game results
results1718 = get_game_results('2017-10-04', '2018-04-08')
results1819 = get_game_results('2018-10-03', '2019-04-06')
results1920 = get_game_results('2019-10-02', '2020-03-12')
results2021 = get_game_results('2021-01-13', '2021-05-06')
# Out:
# Scraping the schedule between 2017-10-04 and 2018-04-08
# Scraping the schedule between 2018-10-03 and 2019-04-06
# Scraping the schedule between 2019-10-02 and 2020-03-12
# Scraping the schedule between 2021-01-13 and 2021-05-06

# %%
display(results1718.shape)
display(results1819.shape)
display(results1920.shape)
display(results2021.shape)
display(results1718.shape[0] + results1819.shape[0] +results1920.shape[0] +results2021.shape[0])
# Out:
# (1271, 12)
# (1272, 12)
# (1083, 12)
# (821, 12)
# 4447

# %%
results1718.head()
# Out:
#       game_id        date                   venue home_team away_team  \
# 0  2017020001  2017-10-04          Bell MTS Place       WPG       TOR
# 1  2017020002  2017-10-04        PPG Paints Arena       PIT       STL
# 2  2017020003  2017-10-04            Rogers Place       EDM       CGY
# 3  2017020004  2017-10-04  SAP Center at San Jose       S.J       PHI
# 4  2017020005  2017-10-05               TD Garden       BOS       NSH
#
#            start_time  home_score  away_score status  Home_Team_Won  \
# 0 2017-10-04 23:00:00           2           7  Final              0
# 1 2017-10-05 00:00:00           4           5  Final              0
# 2 2017-10-05 02:00:00           3           0  Final              1
# 3 2017-10-05 02:30:00           3           5  Final              0
# 4 2017-10-05 23:00:00           4           3  Final              1
#
#     Home_Team_Key   Away_Team_Key
# 0  WPG_2017-10-04  TOR_2017-10-04
# 1  PIT_2017-10-04  STL_2017-10-04
# 2  EDM_2017-10-04  CGY_2017-10-04
# 3  S.J_2017-10-04  PHI_2017-10-04
# 4  BOS_2017-10-05  NSH_2017-10-05

# %%
df_20172018_C = merge_starters_and_features(results1718, goalie_features_dfC, team_stats_all_seasons_sva, elo, feature_columns_all_seasons, goalie_feature_columns)
df_20182019_C = merge_starters_and_features(results1819, goalie_features_dfC, team_stats_all_seasons_sva, elo, feature_columns_all_seasons, goalie_feature_columns)
df_20192020_C = merge_starters_and_features(results1920, goalie_features_dfC, team_stats_all_seasons_sva, elo, feature_columns_all_seasons, goalie_feature_columns)
df_20202021_C = merge_starters_and_features(results2021, goalie_features_dfC, team_stats_all_seasons_sva, elo, feature_columns_all_seasons, goalie_feature_columns)

# %%
all_games_multirolling_SVA_2 = pd.concat([df_20172018_C, df_20182019_C, df_20192020_C, df_20202021_C])

# %%
# some duplicates due to 2 goalies playsing > 28.5 minutes in a game, dropping first
all_games_multirolling_SVA_2 = all_games_multirolling_SVA_2[~all_games_multirolling_SVA_2.duplicated(subset='game_id')]

# %%
all_games_multirolling_SVA_2.shape
# Out:
# (4447, 154)

# %%
all_games_multirolling_SVA_2[all_games_multirolling_SVA_2['home_Rating.A.Pre'].isna()]['home_team'].value_counts()
# Out:
# AMERICAN ALL-STARS    1
# KHI                   1
# Name: home_team, dtype: int64

# %%
#impute goalie stats where lack of games causing NaN
all_games_multirolling_SVA_2['away_Goalie_FenwickSV%'] = np.where(all_games_multirolling_SVA_2['away_Goalie_FenwickSV%'].isna(), ig_FenwickSV,all_games_multirolling_SVA_2['away_Goalie_FenwickSV%'])
all_games_multirolling_SVA_2['away_Goalie_GSAx/60'] = np.where(all_games_multirolling_SVA_2['away_Goalie_GSAx/60'].isna(), ig_GSAx60, all_games_multirolling_SVA_2['away_Goalie_GSAx/60'])
all_games_multirolling_SVA_2['away_Goalie_HDCSV%'] = np.where(all_games_multirolling_SVA_2['away_Goalie_HDCSV%'].isna(), ig_HDCSV, all_games_multirolling_SVA_2['away_Goalie_HDCSV%'])
all_games_multirolling_SVA_2['home_Goalie_FenwickSV%'] = np.where(all_games_multirolling_SVA_2['home_Goalie_FenwickSV%'].isna(), ig_FenwickSV,all_games_multirolling_SVA_2['home_Goalie_FenwickSV%'])
all_games_multirolling_SVA_2['home_Goalie_GSAx/60'] = np.where(all_games_multirolling_SVA_2['home_Goalie_GSAx/60'].isna(), ig_GSAx60, all_games_multirolling_SVA_2['home_Goalie_GSAx/60'])
all_games_multirolling_SVA_2['home_Goalie_HDCSV%'] = np.where(all_games_multirolling_SVA_2['home_Goalie_HDCSV%'].isna(), ig_HDCSV, all_games_multirolling_SVA_2['home_Goalie_HDCSV%'])

# %%
all_games_multirolling_SVA_2.to_csv('data/all_games_multirolling_SVA_2.csv')

# %%
pd.options.display.max_rows = 120
all_games_multirolling_SVA_2.isna().sum()[all_games_multirolling_SVA_2.isna().sum() >25]
# Out:
# Series([], dtype: int64)

# %%
all_games_multirolling_SVA_2[(all_games_multirolling_SVA_2['home_goalie'].isna()) | (all_games_multirolling_SVA_2['away_goalie'].isna())]
# Out:
#         game_id        date               venue           home_team  \
# 0    2018010110  2018-10-03       Lanxess Arena                 KHI
# 903  2018020890  2019-02-15  Xcel Energy Center                 MIN
# 771  2019120001  2020-01-24   Enterprise Center  AMERICAN ALL-STARS
# 848  2019020843  2020-02-08      Bell MTS Place                 WPG
#
#               away_team          start_time  home_score  away_score status  \
# 0                   EDM 2018-10-03 14:00:00           3           4  Final
# 903                 N.J 2019-02-16 01:30:00           4           5  Final
# 771  CANADIAN ALL-STARS 2020-01-25 02:30:00           1           2  Final
# 848                 OTT 2020-02-08 19:00:00           5           2  Final
#
#      Home_Team_Won                  Home_Team_Key  \
# 0                0                 KHI_2018-10-03
# 903              0                 MIN_2019-02-15
# 771              0  AMERICAN ALL-STARS_2020-01-24
# 848              1                 WPG_2020-02-08
#
#                      Away_Team_Key       home_goalie  home_Goalie_FenwickSV%  \
# 0                   EDM_2018-10-03               NaN                0.935086
# 903                 N.J_2019-02-15      Devan Dubnyk                0.931080
# 771  CANADIAN ALL-STARS_2020-01-24               NaN                0.935086
# 848                 OTT_2020-02-08  Laurent Brossoit                0.932864
#
#      home_Goalie_GSAx/60  home_Goalie_HDCSV% away_goalie  \
# 0              -0.255694            0.862060         NaN
# 903            -0.680489            0.837423         NaN
# 771            -0.255694            0.862060         NaN
# 848            -0.165805            0.857143         NaN
#
#      away_Goalie_FenwickSV%  away_Goalie_GSAx/60  away_Goalie_HDCSV%  \
# 0                  0.935086            -0.255694             0.86206
# 903                0.935086            -0.255694             0.86206
# 771                0.935086            -0.255694             0.86206
# 848                0.935086            -0.255694             0.86206
#
#      home_Game_Number   home_Team_Key  home_last_3_FF%_5v5  \
# 0                 NaN             NaN                  NaN
# 903              58.0  MIN_2019-02-15            60.574882
# 771               NaN             NaN                  NaN
# 848              56.0  WPG_2020-02-08            47.894854
#
#      home_last_3_GF%_5v5  home_last_3_xGF%_5v5  home_last_3_SH%  \
# 0                    NaN                   NaN              NaN
# 903            50.543933             61.909759         7.737638
# 771                  NaN                   NaN              NaN
# 848            64.090909             51.523546         9.302019
#
#      home_last3_pp_TOI_per_game  home_last3_xGF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    5.772222                   0.133397
# 771                         NaN                        NaN
# 848                    2.922222                   0.206464
#
#      home_last3_GF_per_min_pp  home_last3_pk_TOI_per_game  \
# 0                         NaN                         NaN
# 903                  0.173244                    6.605556
# 771                       NaN                         NaN
# 848                  0.000000                    3.283333
#
#      home_last3_xGA_per_min_pk  home_last3_GA_per_min_pk home_Last_Game_Date  \
# 0                          NaN                       NaN                 NaT
# 903                   0.124138                  0.151388          2019-02-12
# 771                        NaN                       NaN                 NaT
# 848                   0.227411                  0.101523          2020-02-06
#
#     home_Days_Since_Last_Game  home_B2B  home_last_5_FF%_5v5  \
# 0                         NaT       NaN                  NaN
# 903                    3 days       0.0            60.716365
# 771                       NaT       NaN                  NaN
# 848                    2 days       0.0            49.061647
#
#      home_last_5_GF%_5v5  home_last_5_xGF%_5v5  home_last_5_SH%  \
# 0                    NaN                   NaN              NaN
# 903            50.250501             61.797066         7.015458
# 771                  NaN                   NaN              NaN
# 848            59.976247             50.799290         8.232801
#
#      home_last5_pp_TOI_per_game  home_last5_xGF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    5.463333                   0.098841
# 771                         NaN                        NaN
# 848                    4.200000                   0.175714
#
#      home_last5_GF_per_min_pp  home_last5_pk_TOI_per_game  \
# 0                         NaN                         NaN
# 903                  0.109823                    5.373333
# 771                       NaN                         NaN
# 848                  0.047619                    3.310000
#
#      home_last5_xGA_per_min_pk  home_last5_GA_per_min_pk  \
# 0                          NaN                       NaN
# 903                   0.118362                  0.223325
# 771                        NaN                       NaN
# 848                   0.215710                  0.241692
#
#      home_last_10_FF%_5v5  home_last_10_GF%_5v5  home_last_10_xGF%_5v5  \
# 0                     NaN                   NaN                    NaN
# 903             56.110661             55.980995              58.412397
# 771                   NaN                   NaN                    NaN
# 848             47.027352             40.339531              46.460059
#
#      home_last_10_SH%  home_last10_pp_TOI_per_game  \
# 0                 NaN                          NaN
# 903          7.803187                     5.836667
# 771               NaN                          NaN
# 848          6.778663                     5.081667
#
#      home_last10_xGF_per_min_pp  home_last10_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.074700                   0.119931
# 771                         NaN                        NaN
# 848                    0.130666                   0.039357
#
#      home_last10_pk_TOI_per_game  home_last10_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     5.373333                    0.120968
# 771                          NaN                         NaN
# 848                     4.426667                    0.163780
#
#      home_last10_GA_per_min_pk  home_last_20_FF%_5v5  home_last_20_GF%_5v5  \
# 0                          NaN                   NaN                   NaN
# 903                   0.204715             52.822019             47.766796
# 771                        NaN                   NaN                   NaN
# 848                   0.112952             44.791720             41.030370
#
#      home_last_20_xGF%_5v5  home_last_20_SH%  home_last20_pp_TOI_per_game  \
# 0                      NaN               NaN                          NaN
# 903              54.828125          7.784053                     5.108333
# 771                    NaN               NaN                          NaN
# 848              41.536779          7.636156                     4.467500
#
#      home_last20_xGF_per_min_pp  home_last20_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.093964                   0.107667
# 771                         NaN                        NaN
# 848                    0.135534                   0.123111
#
#      home_last20_pk_TOI_per_game  home_last20_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     5.241667                    0.111033
# 771                          NaN                         NaN
# 848                     4.550000                    0.148352
#
#      home_last20_GA_per_min_pk  home_last_30_FF%_5v5  home_last_30_GF%_5v5  \
# 0                          NaN                   NaN                   NaN
# 903                   0.143084             52.596143             46.602198
# 771                        NaN                   NaN                   NaN
# 848                   0.142857             46.035100             46.564060
#
#      home_last_30_xGF%_5v5  home_last_30_SH%  home_last30_pp_TOI_per_game  \
# 0                      NaN               NaN                          NaN
# 903              54.477004          7.011905                     4.693333
# 771                    NaN               NaN                          NaN
# 848              42.662268          8.326267                     4.622778
#
#      home_last30_xGF_per_min_pp  home_last30_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.098580                   0.106534
# 771                         NaN                        NaN
# 848                    0.122509                   0.129792
#
#      home_last30_pk_TOI_per_game  home_last30_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     4.866111                    0.113780
# 771                          NaN                         NaN
# 848                     4.248333                    0.138956
#
#      home_last30_GA_per_min_pk  home_last_40_FF%_5v5  home_last_40_GF%_5v5  \
# 0                          NaN                   NaN                   NaN
# 903                   0.123302             52.864836             44.930004
# 771                        NaN                   NaN                   NaN
# 848                   0.172617             46.379284             49.675902
#
#      home_last_40_xGF%_5v5  home_last_40_SH%  home_last40_pp_TOI_per_game  \
# 0                      NaN               NaN                          NaN
# 903              54.627574          6.973125                     4.832083
# 771                    NaN               NaN                          NaN
# 848              43.150123          8.595966                     4.657917
#
#      home_last40_xGF_per_min_pp  home_last40_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.095663                   0.134518
# 771                         NaN                        NaN
# 848                    0.114858                   0.118079
#
#      home_last40_pk_TOI_per_game  home_last40_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     4.841667                    0.103838
# 771                          NaN                         NaN
# 848                     4.472917                    0.126204
#
#      home_last40_GA_per_min_pk  away_Game_Number   away_Team_Key  \
# 0                          NaN               NaN             NaN
# 903                   0.118761              58.0  N.J_2019-02-15
# 771                        NaN               NaN             NaN
# 848                   0.150908              55.0  OTT_2020-02-08
#
#      away_last_3_FF%_5v5  away_last_3_GF%_5v5  away_last_3_xGF%_5v5  \
# 0                    NaN                  NaN                   NaN
# 903            41.453220            34.120027             47.913043
# 771                  NaN                  NaN                   NaN
# 848            44.268913            27.310345             44.021739
#
#      away_last_3_SH%  away_last3_pp_TOI_per_game  away_last3_xGF_per_min_pp  \
# 0                NaN                         NaN                        NaN
# 903         7.746479                    5.066667                   0.135526
# 771              NaN                         NaN                        NaN
# 848         3.261407                    6.016667                   0.111911
#
#      away_last3_GF_per_min_pp  away_last3_pk_TOI_per_game  \
# 0                         NaN                         NaN
# 903                  0.197368                    6.338889
# 771                       NaN                         NaN
# 848                  0.110803                    3.538889
#
#      away_last3_xGA_per_min_pk  away_last3_GA_per_min_pk away_Last_Game_Date  \
# 0                          NaN                       NaN                 NaT
# 903                   0.127783                  0.052585          2019-02-14
# 771                        NaN                       NaN                 NaT
# 848                   0.128100                  0.282575          2020-02-06
#
#     away_Days_Since_Last_Game  away_B2B  away_last_5_FF%_5v5  \
# 0                         NaT       NaN                  NaN
# 903                    1 days       1.0            41.738354
# 771                       NaT       NaN                  NaN
# 848                    2 days       0.0            46.622492
#
#      away_last_5_GF%_5v5  away_last_5_xGF%_5v5  away_last_5_SH%  \
# 0                    NaN                   NaN              NaN
# 903            36.142923             44.496763         7.665404
# 771                  NaN                   NaN              NaN
# 848            23.763179             47.371676         2.655429
#
#      away_last5_pp_TOI_per_game  away_last5_xGF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    5.040000                   0.113889
# 771                         NaN                        NaN
# 848                    5.573333                   0.121292
#
#      away_last5_GF_per_min_pp  away_last5_pk_TOI_per_game  \
# 0                         NaN                         NaN
# 903                  0.119048                    6.236667
# 771                       NaN                         NaN
# 848                  0.215311                    5.303333
#
#      away_last5_xGA_per_min_pk  away_last5_GA_per_min_pk  \
# 0                          NaN                       NaN
# 903                   0.131801                  0.064137
# 771                        NaN                       NaN
# 848                   0.127844                  0.188561
#
#      away_last_10_FF%_5v5  away_last_10_GF%_5v5  away_last_10_xGF%_5v5  \
# 0                     NaN                   NaN                    NaN
# 903             43.970655             36.261591              44.473684
# 771                   NaN                   NaN                    NaN
# 848             42.821991             34.004237              41.947667
#
#      away_last_10_SH%  away_last10_pp_TOI_per_game  \
# 0                 NaN                          NaN
# 903          7.449742                     6.161667
# 771               NaN                          NaN
# 848          4.356480                     5.071667
#
#      away_last10_xGF_per_min_pp  away_last10_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.103868                   0.129835
# 771                         NaN                        NaN
# 848                    0.138613                   0.177456
#
#      away_last10_pk_TOI_per_game  away_last10_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     5.838333                    0.104311
# 771                          NaN                         NaN
# 848                     5.141667                    0.126224
#
#      away_last10_GA_per_min_pk  away_last_20_FF%_5v5  away_last_20_GF%_5v5  \
# 0                          NaN                   NaN                   NaN
# 903                   0.102769             44.377892             42.627128
# 771                        NaN                   NaN                   NaN
# 848                   0.136143             42.805975             36.397968
#
#      away_last_20_xGF%_5v5  away_last_20_SH%  away_last20_pp_TOI_per_game  \
# 0                      NaN               NaN                          NaN
# 903              44.967459          8.687646                     5.608333
# 771                    NaN               NaN                          NaN
# 848              43.240789          6.392663                     5.040833
#
#      away_last20_xGF_per_min_pp  away_last20_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.101813                   0.115899
# 771                         NaN                        NaN
# 848                    0.126170                   0.148785
#
#      away_last20_pk_TOI_per_game  away_last20_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     5.361667                     0.09857
# 771                          NaN                         NaN
# 848                     4.250833                     0.11339
#
#      away_last20_GA_per_min_pk  away_last_30_FF%_5v5  away_last_30_GF%_5v5  \
# 0                          NaN                   NaN                   NaN
# 903                   0.093255             45.243536             42.154787
# 771                        NaN                   NaN                   NaN
# 848                   0.164674             45.833907             39.020435
#
#      away_last_30_xGF%_5v5  away_last_30_SH%  away_last30_pp_TOI_per_game  \
# 0                      NaN               NaN                          NaN
# 903              45.387980          8.093826                     5.578333
# 771                    NaN               NaN                          NaN
# 848              46.905941          7.013964                     4.776111
#
#      away_last30_xGF_per_min_pp  away_last30_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.106424                   0.107559
# 771                         NaN                        NaN
# 848                    0.123880                   0.125625
#
#      away_last30_pk_TOI_per_game  away_last30_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     5.480000                    0.087409
# 771                          NaN                         NaN
# 848                     4.802778                    0.112019
#
#      away_last30_GA_per_min_pk  away_last_40_FF%_5v5  away_last_40_GF%_5v5  \
# 0                          NaN                   NaN                   NaN
# 903                   0.079075              46.87493             42.728749
# 771                        NaN                   NaN                   NaN
# 848                   0.145749              46.69922             42.722346
#
#      away_last_40_xGF%_5v5  away_last_40_SH%  away_last40_pp_TOI_per_game  \
# 0                      NaN               NaN                          NaN
# 903              47.676528          7.893694                     5.357083
# 771                    NaN               NaN                          NaN
# 848              48.480580          7.337772                     4.758750
#
#      away_last40_xGF_per_min_pp  away_last40_GF_per_min_pp  \
# 0                           NaN                        NaN
# 903                    0.105888                   0.098001
# 771                         NaN                        NaN
# 848                    0.113265                   0.115577
#
#      away_last40_pk_TOI_per_game  away_last40_xGA_per_min_pk  \
# 0                            NaN                         NaN
# 903                     5.205417                    0.088418
# 771                          NaN                         NaN
# 848                     4.805417                    0.102957
#
#      away_last40_GA_per_min_pk  home_Rating.A.Pre  away_Rating.A.Pre  \
# 0                          NaN                NaN                NaN
# 903                   0.086448            1499.33            1456.88
# 771                        NaN                NaN                NaN
# 848                   0.124859            1508.78            1431.58
#
#     B2B_Status     Season
# 0            0  2018-2019
# 903  Away_only  2018-2019
# 771          0  2019-2020
# 848    Neither  2019-2020
